# %%
import numpy as np
import pandas as pd
import torch
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from skimage import io as image_io
from torch import optim
import timm
from tqdm import tqdm
# from CLAM.models.model_clam import CLAM_SB

# %%
df = pd.read_csv('/mnt/d/uczelnia/magister/TCGA_breast_patch/metadata.csv', index_col=0)
df['patient_id'] = df['file_name'].apply(lambda x: x.split('/')[6])
df.set_index(['patient_id', 'file_name'], inplace=True)

# %%
df.head()
# Out:
#                                                                                 label
# patient_id               file_name
# TCGA-3C-AALI-01A-01-T_R1 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+

# %%
def get_train_test_split(df: pd.DataFrame, group_sample_size: int=50, target_column: str="label", same_train_classes_count: bool = False):
    test_df = pd.DataFrame(columns=df.columns)
    for c in df[target_column].unique():
        selected_ids = np.random.choice([elem[0] for elem in df.index[df['label'] == 'hr+her2+']], group_sample_size, replace=False)
        
        test_df = pd.concat([df.loc[selected_ids], test_df.loc[:]])
    train_df = df.loc[~df.index.isin(test_df.index)]
    
    if same_train_classes_count:
        train_df2 = pd.DataFrame(columns=df.columns)
        max_sample = np.min(df[target_column].value_counts().iloc[0:3].to_numpy())
        for c in df[target_column].unique():
            train_df2 = pd.concat([df[df[target_column] == c].sample(max_sample, random_state=420).loc[:], train_df2.loc[:]])
        train_df = train_df2

    return train_df, test_df

train_df, test_df = get_train_test_split(df)

# %%
selected_ids = np.random.choice([elem[0] for elem in df.index[df['label'] == 'hr+her2+']], 50, replace=False)
df.loc[selected_ids]
# Out:
#                                                                                 label
# patient_id               file_name
# TCGA-AO-A12G-01A-01-B_R2 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# ...                                                                               ...
# TCGA-BH-A18P-11A-01-T_R2 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#
# [25876 rows x 1 columns]

# %%
selected_ids = np.random.choice([elem[0] for elem in df.index[df['label'] == 'hr-']], 50, replace=False)
df.loc[selected_ids]
# Out:
#                                                                             label
# patient_id               file_name
# TCGA-BH-A0AV-01A-03-B_R2 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
# ...                                                                           ...
# TCGA-A7-A0CE-01A-01-T_R1 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...   hr-
#
# [29662 rows x 1 columns]

# %%
len(set([elem[0] for elem in df.index[df['label'] == 'hr-'].to_list()]))
# Out:
# 532

# %%
data_transforms = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((224, 224)),
        # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
class TCGABags(Dataset):
    def __init__(self, df, labels, bag_len=10, mean_bag_length=10, var_bag_length=1, num_bag=1000, seed=7, train=True, transform = data_transforms):
        self.transform = transform
        self.mean_bag_length = mean_bag_length
        self.var_bag_length = var_bag_length
        self.num_bag = num_bag
        self.seed = seed
        self.train = train
        self.df = df
        self.idx = df.index.get_level_values(0).unique()
        self.labels = labels
        self.bag_len = bag_len

        self.r = np.random.RandomState(seed)
        
    def _form_bags(self, df: pd.Series):
        bags_list = []
        labels_list = []

        for i in df.index.get_level_values(0).unique():
            df.loc[i].sample()
            for j in df.loc[i].index:
                img = image_io.imread(j)

        return bags_list, labels_list

    def __len__(self):
        return len(self.idx)

    def __getitem__(self, index):
        batch = self.df.loc[self.idx[index]].sample(self.bag_len, replace=True)
        label = self.labels.index(batch.iloc[0, 0])
        res = torch.empty((10, 3, 224, 224))
        for i, fname in enumerate(batch.index):
            img = image_io.imread(fname)
            if self.transform:
                res[i] = self.transform(img)
        perm = res
        return perm, label
    
dl = DataLoader(TCGABags(df, ['hr+her2-', 'hr-', 'hr+her2+']), batch_size=1)
img, label = next(iter(dl))
img.shape
# Out:
# torch.Size([1, 10, 3, 224, 224])

# %%
class TimmCNNEncoder(torch.nn.Module):
    def __init__(self, model_name: str = 'resnet50.tv_in1k', 
                 kwargs: dict = {'features_only': True, 'out_indices': (3,), 'pretrained': True, 'num_classes': 3}, 
                 pool: bool = True):
        super().__init__()
        assert kwargs.get('pretrained', False), 'only pretrained models are supported'
        self.model = timm.create_model(model_name, **kwargs)
        self.model_name = model_name
        if pool:
            self.pool = torch.nn.AdaptiveAvgPool2d(1)
        else:
            self.pool = None
    
    def forward(self, x):
        out = self.model(x)
        if isinstance(out, list):
            assert len(out) == 1
            out = out[0]
        if self.pool:
            out = self.pool(out).squeeze(-1).squeeze(-1)
        return out

# %%
class Attn_Net(nn.Module):

    def __init__(self, L = 1024, D = 256, dropout = False, n_classes = 1):
        super(Attn_Net, self).__init__()
        self.module = [
            nn.Linear(L, D),
            nn.Tanh()]

        if dropout:
            self.module.append(nn.Dropout(0.25))

        self.module.append(nn.Linear(D, n_classes))
        
        self.module = nn.Sequential(*self.module)
    
    def forward(self, x):
        return self.module(x), x # N x n_classes

"""
Attention Network with Sigmoid Gating (3 fc layers)
args:
    L: input feature dimension
    D: hidden layer dimension
    dropout: whether to use dropout (p = 0.25)
    n_classes: number of classes 
"""
class Attn_Net_Gated(nn.Module):
    def __init__(self, L = 1024, D = 256, dropout = False, n_classes = 1):
        super(Attn_Net_Gated, self).__init__()
        self.attention_a = [
            nn.Linear(L, D),
            nn.Tanh()]
        
        self.attention_b = [nn.Linear(L, D),
                            nn.Sigmoid()]
        if dropout:
            self.attention_a.append(nn.Dropout(0.25))
            self.attention_b.append(nn.Dropout(0.25))

        self.attention_a = nn.Sequential(*self.attention_a)
        self.attention_b = nn.Sequential(*self.attention_b)
        
        self.attention_c = nn.Linear(D, n_classes)

    def forward(self, x):
        a = self.attention_a(x)
        b = self.attention_b(x)
        A = a.mul(b)
        A = self.attention_c(A)  # N x n_classes
        return A, x

"""
args:
    gate: whether to use gated attention network
    size_arg: config for network size
    dropout: whether to use dropout
    k_sample: number of positive/neg patches to sample for instance-level training
    dropout: whether to use dropout (p = 0.25)
    n_classes: number of classes 
    instance_loss_fn: loss function to supervise instance-level training
    subtyping: whether it's a subtyping problem
"""
class CLAM_SB(nn.Module):
    def __init__(self, gate = True, size_arg = "small", dropout = 0., k_sample=3, n_classes=2,
        instance_loss_fn=nn.CrossEntropyLoss(), subtyping=True, embed_dim=1024):
        super().__init__()
        # self.size_dict = {"small": [embed_dim, 512, 256], "big": [embed_dim, 512, 384]}
        self.size_dict = {"small": [embed_dim, 224, 224], "big": [embed_dim, 512, 384]}
        size = self.size_dict[size_arg]
        fc = [nn.Linear(size[0], size[1]), nn.ReLU(), nn.Dropout(dropout)]
        if gate:
            attention_net = Attn_Net_Gated(L = size[1], D = size[2], dropout = dropout, n_classes = 1)
        else:
            attention_net = Attn_Net(L = size[1], D = size[2], dropout = dropout, n_classes = 1)
        fc.append(attention_net)
        self.attention_net = nn.Sequential(*fc)
        self.classifiers = nn.Linear(size[1], n_classes)
        instance_classifiers = [nn.Linear(size[1], 2) for i in range(n_classes)]
        self.instance_classifiers = nn.ModuleList(instance_classifiers)
        self.k_sample = k_sample
        self.instance_loss_fn = instance_loss_fn
        self.n_classes = n_classes
        self.subtyping = subtyping
    
    @staticmethod
    def create_positive_targets(length, device):
        return torch.full((length, ), 1, device=device).long()
    
    @staticmethod
    def create_negative_targets(length, device):
        return torch.full((length, ), 0, device=device).long()
    
    #instance-level evaluation for in-the-class attention branch
    def inst_eval(self, A, h, classifier): 
        device=h.device
        if len(A.shape) == 1:
            A = A.view(1, -1)
        top_p_ids = torch.topk(A, self.k_sample)[1][-1]
        top_p = torch.index_select(h, dim=0, index=top_p_ids)
        top_n_ids = torch.topk(-A, self.k_sample, dim=1)[1][-1]
        top_n = torch.index_select(h, dim=0, index=top_n_ids)
        p_targets = self.create_positive_targets(self.k_sample, device)
        n_targets = self.create_negative_targets(self.k_sample, device)

        all_targets = torch.cat([p_targets, n_targets], dim=0)
        all_instances = torch.cat([top_p, top_n], dim=0)
        logits = classifier(all_instances)
        all_preds = torch.topk(logits, 1, dim = 1)[1].squeeze(1)
        instance_loss = self.instance_loss_fn(logits, all_targets)
        return instance_loss, all_preds, all_targets
    
    #instance-level evaluation for out-of-the-class attention branch
    def inst_eval_out(self, A, h, classifier):
        device=h.device
        if len(A.shape) == 1:
            A = A.view(1, -1)
        top_p_ids = torch.topk(A, self.k_sample)[1][-1]
        # print(top_p_ids)
        top_p = torch.index_select(h, dim=0, index=top_p_ids)
        p_targets = self.create_negative_targets(self.k_sample, device)
        logits = classifier(top_p)
        p_preds = torch.topk(logits, 1, dim = 1)[1].squeeze(1)
        instance_loss = self.instance_loss_fn(logits, p_targets)
        return instance_loss, p_preds, p_targets

    def forward(self, h, label=None, instance_eval=False, return_features=False, attention_only=False):
        A, h = self.attention_net(h)  # NxK        
        A = torch.transpose(A, 1, 0)  # KxN
        if attention_only:
            return A
        A_raw = A
        A = F.softmax(A, dim=1)  # softmax over N

        if instance_eval:
            total_inst_loss = 0.0
            all_preds = []
            all_targets = []
            inst_labels = F.one_hot(label, num_classes=self.n_classes).squeeze() #binarize label
            for i in range(len(self.instance_classifiers)):
                inst_label = inst_labels[i].item()
                classifier = self.instance_classifiers[i]
                if inst_label == 1: #in-the-class:
                    instance_loss, preds, targets = self.inst_eval(A, h, classifier)
                    all_preds.extend(preds.cpu().numpy())
                    all_targets.extend(targets.cpu().numpy())
                else: #out-of-the-class
                    if self.subtyping:
                        instance_loss, preds, targets = self.inst_eval_out(A, h, classifier)
                        all_preds.extend(preds.cpu().numpy())
                        all_targets.extend(targets.cpu().numpy())
                    else:
                        continue
                total_inst_loss += instance_loss

            if self.subtyping:
                total_inst_loss /= len(self.instance_classifiers)
                
        M = torch.mm(A, h) 
        logits = self.classifiers(M)
        Y_hat = torch.topk(logits, 1, dim = 1)[1]
        Y_prob = F.softmax(logits, dim = 1)
        if instance_eval:
            results_dict = {'instance_loss': total_inst_loss, 'inst_labels': np.array(all_targets), 
            'inst_preds': np.array(all_preds)}
        else:
            results_dict = {}
        if return_features:
            results_dict.update({'features': M})
        return logits, Y_prob, Y_hat, A_raw, results_dict

# %%
list(set(train_df.index.levels[0]) & set(test_df.index.levels[0]))
# Out:
# ['TCGA-A7-A13F-01A-01-T_R2',
#  'TCGA-E9-A1N5-11A-03-T_R2',
#  'TCGA-BH-A18P-11A-01-T_R2',
#  'TCGA-AC-A62Y-01A-01-T_R4',
#  'TCGA-A7-A0CJ-01A-02-T_R2',
#  'TCGA-AO-A0JF-01A-01-B_R1',
#  'TCGA-AN-A0AL-01A-01-B_R3',
#  'TCGA-AO-A0JL-01A-01-T_R2',
#  'TCGA-A1-A0SO-01A-02-T_R2',
#  'TCGA-S3-AA0Z-01A-01-T_R2',
#  'TCGA-A8-A09X-01A-01-B_R1',
#  'TCGA-A2-A0T1-01A-02-T_R1',
#  'TCGA-LL-A7T0-01A-03-T_R1',
#  'TCGA-AC-A2FF-01A-01-T_R1',
#  'TCGA-BH-A18J-11A-02-T_R1',
#  'TCGA-A8-A09Q-01A-01-B_R2',
#  'TCGA-A8-A07L-01A-01-B_R1',
#  'TCGA-BH-A0BZ-01A-03-B_R1',
#  'TCGA-BH-A0H7-01A-01-T_R2',
#  'TCGA-AO-A0JC-01A-01-B_R1',
#  'TCGA-BH-A0C3-01A-02-T_R1',
#  'TCGA-AO-A12E-01A-01-B_R1',
#  'TCGA-E2-A1BC-11A-03-T_R1',
#  'TCGA-A7-A6VY-01A-01-T_R1',
#  'TCGA-AN-A0XO-01A-01-T_R1',
#  'TCGA-BH-A0E6-01A-01-T_R1',
#  'TCGA-E9-A1NI-01A-01-T_R1',
#  'TCGA-E2-A15P-01A-01-T_R1',
#  'TCGA-A8-A096-01A-01-B_R1',
#  'TCGA-AC-A62Y-01A-01-T_R3',
#  'TCGA-D8-A1XS-01A-01-T_R1',
#  'TCGA-A7-A4SA-11A-01-T_R2',
#  'TCGA-A8-A07R-01A-01-B_R2',
#  'TCGA-AQ-A1H3-01A-03-T_R1',
#  'TCGA-E2-A15M-11A-02-T_R1',
#  'TCGA-BH-A28O-01A-01-M_R2',
#  'TCGA-A8-A09M-01A-01-T_R3',
#  'TCGA-A8-A090-01A-01-T_R1',
#  'TCGA-A2-A0CV-01A-03-T_R2',
#  'TCGA-A8-A0A7-01A-01-B_R1',
#  'TCGA-A7-A26I-01A-01-T_R1',
#  'TCGA-BH-A0B5-01A-01-B_R1',
#  'TCGA-BH-A0HA-01A-01-B_R1',
#  'TCGA-A8-A0AB-01A-01-T_R2',
#  'TCGA-BH-AB28-11A-02-T_R2',
#  'TCGA-E9-A1NE-11A-01-T_R1',
#  'TCGA-E2-A15I-11A-01-T_R1',
#  'TCGA-A7-A13D-01A-01-B_R1',
#  'TCGA-AN-A0FF-01A-01-T_R1',
#  'TCGA-BH-A0EA-01A-01-M_R1',
#  'TCGA-A2-A25A-01A-01-T_R2',
#  'TCGA-AR-A0TY-01A-01-T_R2',
#  'TCGA-E9-A1NF-11A-05-T_R1',
#  'TCGA-BH-A0DQ-01A-01-M_R1',
#  'TCGA-E9-A1NH-11A-01-T_R1',
#  'TCGA-A2-A25D-01A-01-T_R2',
#  'TCGA-D8-A1J9-01A-01-T_R1',
#  'TCGA-E2-A158-01A-01-T_R1',
#  'TCGA-A2-A0SV-01A-01-B_R1',
#  'TCGA-E2-A15T-01A-01-T_R1',
#  'TCGA-A8-A09C-01A-01-T_R1',
#  'TCGA-A8-A09M-01A-01-B_R2',
#  'TCGA-A7-A4SA-11A-02-T_R4',
#  'TCGA-A8-A085-01A-01-B_R1',
#  'TCGA-A2-A1FZ-01A-05-T_R1',
#  'TCGA-AO-A0J2-01A-01-B_R1',
#  'TCGA-D8-A1JT-01A-03-T_R2',
#  'TCGA-BH-A0H9-11A-02-B_R1',
#  'TCGA-E9-A1N9-01A-01-T_R2',
#  'TCGA-AC-A3TN-01A-01-T_R2',
#  'TCGA-E2-A15M-11A-02-T_R3',
#  'TCGA-A2-A0YT-01A-01-B_R1',
#  'TCGA-E2-A153-11A-02-T_R2',
#  'TCGA-GM-A3NY-01A-01-T_R2',
#  'TCGA-BH-A1F6-11B-09-T_R1',
#  'TCGA-AR-A0TZ-01A-01-B_R1',
#  'TCGA-GM-A2DN-01A-01-T_R1',
#  'TCGA-E2-A1L7-01A-01-T_R2',
#  'TCGA-A2-A04V-01A-02-B_R1',
#  'TCGA-A8-A07O-01A-01-T_R1',
#  'TCGA-D8-A1JJ-01A-03-T_R1',
#  'TCGA-EW-A1PB-01A-01-T_R1',
#  'TCGA-BH-A0AU-11A-01-T_R1',
#  'TCGA-A2-A04U-01A-01-B_R2',
#  'TCGA-A2-A4S0-01A-02-T_R1',
#  'TCGA-A8-A08J-01A-01-T_R1',
#  'TCGA-A7-A0CE-11A-01-B_R2',
#  'TCGA-OK-A5Q2-01A-01-T_R5',
#  'TCGA-E2-A1LG-11A-01-T_R1',
#  'TCGA-AR-A2LO-01A-03-T_R2',
#  'TCGA-BH-A18U-11A-02-T_R3',
#  'TCGA-A7-A4SD-11A-02-T_R1',
#  'TCGA-BH-A0AY-01A-02-B_R2',
#  'TCGA-E2-A15R-01A-01-T_R2',
#  'TCGA-AO-A0JA-01A-01-T_R1',
#  'TCGA-A2-A0CZ-01A-01-T_R2',
#  'TCGA-A2-A0ES-01A-01-B_R1',
#  'TCGA-A8-A09N-01A-01-T_R1',
#  'TCGA-A2-A0YD-01A-01-B_R1',
#  'TCGA-D8-A13Z-01A-01-T_R2',
#  'TCGA-D8-A1J8-01A-01-T_R2',
#  'TCGA-BH-A0B5-11A-02-T_R1',
#  'TCGA-A8-A06Y-01A-02-B_R2',
#  'TCGA-AO-A12F-01A-01-B_R2',
#  'TCGA-S3-A6ZF-01A-03-T_R1',
#  'TCGA-BH-A0HQ-01A-01-T_R2',
#  'TCGA-A2-A0CT-01A-02-B_R1',
#  'TCGA-A8-A07E-01A-01-B_R3',
#  'TCGA-E9-A1NC-01A-02-T_R1',
#  'TCGA-BH-A0BZ-01A-03-T_R1',
#  'TCGA-BH-A1F6-11B-09-T_R3',
#  'TCGA-EW-A2FS-01A-01-T_R1',
#  'TCGA-EW-A1IX-01A-01-T_R2',
#  'TCGA-OK-A5Q2-01A-01-T_R2',
#  'TCGA-A8-A08R-01A-01-B_R1',
#  'TCGA-A2-A25F-01A-01-T_R4',
#  'TCGA-BH-A0AZ-01A-02-T_R1',
#  'TCGA-3C-AALI-01A-01-T_R2',
#  'TCGA-BH-A0HB-01A-01-M_R2',
#  'TCGA-LD-A7W5-01A-02-T_R1',
#  'TCGA-AO-A0JC-01A-01-T_R2',
#  'TCGA-A8-A08G-01A-01-T_R2',
#  'TCGA-BH-A0BZ-11A-06-T_R2',
#  'TCGA-BH-A18P-11A-01-T_R1',
#  'TCGA-BH-A18T-11A-01-T_R3',
#  'TCGA-BH-A0BF-11A-01-T_R3',
#  'TCGA-AN-A0XP-01A-01-B_R2',
#  'TCGA-E2-A1LG-11A-04-T_R2',
#  'TCGA-BH-A1FD-11B-02-T_R2',
#  'TCGA-BH-A1EX-11A-01-T_R2',
#  'TCGA-A2-A0YF-01A-02-T_R1',
#  'TCGA-OL-A5DA-01A-01-T_R2',
#  'TCGA-BH-A0DE-01A-01-T_R2',
#  'TCGA-A7-A6VV-01A-02-T_R2',
#  'TCGA-AN-A0XV-01A-01-T_R1',
#  'TCGA-BH-A0DI-11A-02-T_R4',
#  'TCGA-BH-A1EY-11A-01-T_R1',
#  'TCGA-GM-A2DH-01A-01-T_R3',
#  'TCGA-BH-A1F6-11B-09-T_R4',
#  'TCGA-A2-A0EW-01A-02-T_R2',
#  'TCGA-E2-A153-01A-01-T_R1',
#  'TCGA-E2-A1LG-11A-03-T_R1',
#  'TCGA-AO-A1KS-01A-01-T_R2',
#  'TCGA-BH-A0H6-01A-02-B_R3',
#  'TCGA-A7-A13E-01B-04-B_R1',
#  'TCGA-AO-A1KR-01A-01-T_R1',
#  'TCGA-BH-A0BO-01A-01-B_R4',
#  'TCGA-AO-A0JG-01A-03-B_R1',
#  'TCGA-E2-A1LG-11A-04-T_R1',
#  'TCGA-A2-A25D-01A-01-T_R1',
#  'TCGA-S3-AA12-01A-01-T_R1',
#  'TCGA-AO-A0J3-01A-01-B_R1',
#  'TCGA-A7-A0D9-11A-05-T_R2',
#  'TCGA-A2-A0CQ-01A-02-B_R1',
#  'TCGA-E9-A1NH-01A-01-T_R1',
#  'TCGA-A8-A09D-01A-01-T_R1',
#  'TCGA-BH-A18K-11A-02-T_R2',
#  'TCGA-A7-A0D9-11A-05-T_R1',
#  'TCGA-OL-A6VO-01A-01-T_R1',
#  'TCGA-BH-A18M-11A-03-T_R1',
#  'TCGA-AO-A03R-01A-01-B_R3',
#  'TCGA-AR-A1AN-01A-01-T_R1',
#  'TCGA-A8-A07O-01A-01-T_R2',
#  'TCGA-AO-A0J3-01A-01-B_R2',
#  'TCGA-AQ-A1H2-01A-01-T_R1',
#  'TCGA-BH-A1ET-11B-01-T_R2',
#  'TCGA-E2-A15D-01A-01-T_R1',
#  'TCGA-BH-A18I-01A-01-T_R1',
#  'TCGA-BH-A0BL-01A-01-T_R1',
#  'TCGA-AR-A0TW-01A-01-T_R2',
#  'TCGA-BH-A18L-11A-04-T_R2',
#  'TCGA-BH-A0BD-01A-01-B_R2',
#  'TCGA-AR-A0TQ-01A-01-B_R2',
#  'TCGA-A8-A06Q-01A-01-B_R1',
#  'TCGA-A8-A09Z-01A-01-B_R2',
#  'TCGA-E2-A3DX-01A-02-T_R1',
#  'TCGA-BH-A28Q-01A-01-T_R2',
#  'TCGA-A2-A3KC-01A-01-T_R2',
#  'TCGA-AR-A0TT-01A-03-B_R1',
#  'TCGA-A2-A0YK-01A-02-T_R1',
#  'TCGA-BH-A0BL-11A-01-B_R1',
#  'TCGA-A2-A0CW-01A-02-T_R2',
#  'TCGA-A7-A4SC-11A-04-T_R2',
#  'TCGA-D8-A142-01A-01-T_R2',
#  'TCGA-E9-A1NG-11A-04-T_R2',
#  'TCGA-A2-A4RY-01A-03-T_R2',
#  'TCGA-PE-A5DD-01A-01-T_R1',
#  'TCGA-D8-A143-01A-01-T_R1',
#  'TCGA-D8-A142-01A-01-T_R1',
#  'TCGA-BH-A0HA-11A-03-T_R1',
#  'TCGA-BH-A0BS-01A-01-B_R1',
#  'TCGA-E2-A1LS-11A-03-T_R1',
#  'TCGA-AC-A62Y-01A-01-T_R5',
#  'TCGA-A7-A4SC-01A-01-T_R1',
#  'TCGA-AR-A2LQ-01A-02-T_R1',
#  'TCGA-BH-A0DO-01B-01-B_R1',
#  'TCGA-A8-A07P-01A-01-T_R2',
#  'TCGA-BH-A0DI-11A-03-T_R4',
#  'TCGA-A2-A0T4-01A-03-T_R2',
#  'TCGA-A8-A09B-01A-01-T_R1',
#  'TCGA-AO-A12G-01A-01-T_R1',
#  'TCGA-AO-A0JC-01A-01-B_R2',
#  'TCGA-AC-A3QQ-01A-01-T_R2',
#  'TCGA-BH-A1FC-11A-01-T_R3',
#  'TCGA-E2-A15D-01A-01-T_R2',
#  'TCGA-BH-A1EV-11A-01-T_R2',
#  'TCGA-A8-A085-01A-01-B_R3',
#  'TCGA-AN-A0FF-01A-01-B_R2',
#  'TCGA-D8-A1XD-01A-01-T_R1',
#  'TCGA-A8-A090-01A-01-B_R3',
#  'TCGA-A7-A0DA-01A-03-T_R1',
#  'TCGA-AO-A0J6-01A-01-B_R3',
#  'TCGA-BH-A0BO-01A-01-B_R3',
#  'TCGA-AO-A03V-01A-01-M_R1',
#  'TCGA-A1-A0SF-01A-01-T_R2',
#  'TCGA-D8-A1XB-01A-01-T_R2',
#  'TCGA-A2-A0CP-01A-01-T_R2',
#  'TCGA-E2-A1IO-01A-01-T_R2',
#  'TCGA-OL-A5DA-01A-01-T_R1',
#  'TCGA-AR-A0TQ-01A-01-T_R2',
#  'TCGA-A2-A0YG-01A-02-B_R1',
#  'TCGA-BH-A0BF-01A-02-T_R2',
#  'TCGA-AC-A3YI-01A-02-T_R1',
#  'TCGA-A2-A04R-01A-04-B_R2',
#  'TCGA-BH-A0BD-01A-01-B_R1',
#  'TCGA-A8-A099-01A-01-B_R3',
#  'TCGA-AQ-A1H3-01A-03-T_R2',
#  'TCGA-BH-A1EN-11A-01-T_R2',
#  'TCGA-A8-A090-01A-01-B_R2',
#  'TCGA-AC-A23H-01A-01-T_R1',
#  'TCGA-E2-A15T-01A-01-T_R2',
#  'TCGA-LQ-A4E4-01A-01-T_R1',
#  'TCGA-E9-A1N4-01A-01-T_R1',
#  'TCGA-A7-A4SC-11A-01-T_R1',
#  'TCGA-A2-A04U-01A-01-T_R1',
#  'TCGA-A8-A09N-01A-01-T_R2',
#  'TCGA-A8-A086-01A-01-B_R1',
#  'TCGA-BH-A0DX-01A-01-B_R2',
#  'TCGA-AN-A0FF-01A-01-T_R2',
#  'TCGA-BH-A0DI-11A-02-T_R3',
#  'TCGA-A2-A0CZ-01A-01-B_R3',
#  'TCGA-BH-A0BG-01A-01-B_R1',
#  'TCGA-BH-A0BO-01A-01-B_R2',
#  'TCGA-A2-A0EM-01A-01-B_R1',
#  'TCGA-A8-A08H-01A-01-B_R1',
#  'TCGA-EW-A1IY-01A-01-T_R2',
#  'TCGA-E2-A1LH-11A-02-T_R1',
#  'TCGA-A8-A09E-01A-01-B_R1',
#  'TCGA-BH-A18S-11A-02-T_R2',
#  'TCGA-A8-A07S-01A-01-B_R1',
#  'TCGA-OL-A66I-01A-02-T_R2',
#  'TCGA-BH-A0DT-11A-03-T_R1',
#  'TCGA-AR-A1AP-01A-01-T_R1',
#  'TCGA-E2-A158-01A-01-T_R2',
#  'TCGA-AC-A3YI-01A-02-T_R2',
#  'TCGA-BH-A0H7-01A-01-M_R1',
#  'TCGA-AN-A0XL-01A-01-B_R2',
#  'TCGA-A2-A0CR-01A-01-B_R2',
#  'TCGA-E9-A295-01A-01-T_R2',
#  'TCGA-A7-A4SE-11A-01-T_R1',
#  'TCGA-E2-A10F-01A-01-T_R4',
#  'TCGA-AO-A03R-01A-02-B_R3',
#  'TCGA-E2-A1LE-01A-01-T_R1',
#  'TCGA-A2-A0EV-01A-01-B_R1',
#  'TCGA-BH-A0DS-01A-01-T_R2',
#  'TCGA-AC-A5XS-01A-01-T_R1',
#  'TCGA-AO-A126-01A-01-B_R3',
#  'TCGA-E2-A1BC-11A-02-T_R1',
#  'TCGA-AR-A1AT-01A-01-T_R1',
#  'TCGA-BH-A0BF-01A-02-B_R4',
#  'TCGA-BH-A0DD-11A-05-T_R4',
#  'TCGA-AR-A1AM-01A-04-T_R1',
#  'TCGA-BH-A0AZ-11A-02-B_R2',
#  'TCGA-AQ-A54O-01A-01-T_R2',
#  'TCGA-A7-A4SA-11A-01-T_R1',
#  'TCGA-AC-A2BK-11A-01-T_R1',
#  'TCGA-AN-A0XU-01A-01-T_R1',
#  'TCGA-AO-A0JL-01A-01-T_R1',
#  'TCGA-BH-A0HF-01A-01-T_R1',
#  'TCGA-EW-A1IX-01A-01-T_R1',
#  'TCGA-BH-A0DL-01A-01-B_R2',
#  'TCGA-D8-A1XZ-01A-01-T_R2',
#  'TCGA-A8-A09Q-01A-01-B_R1',
#  'TCGA-AR-A24V-01A-02-T_R2',
#  'TCGA-A1-A0SP-01A-01-B_R2',
#  'TCGA-BH-A0EI-01A-01-B_R2',
#  'TCGA-D8-A1XG-01A-01-T_R2',
#  'TCGA-LD-A74U-01A-01-T_R2',
#  'TCGA-A2-A1FV-01A-01-T_R2',
#  'TCGA-AN-A041-01A-01-B_R1',
#  'TCGA-OL-A5RV-01A-01-T_R1',
#  'TCGA-A2-A1FW-01A-01-T_R1',
#  'TCGA-D8-A1XG-01A-01-T_R1',
#  'TCGA-E2-A1LK-01A-02-T_R4',
#  'TCGA-AC-A5XU-01A-01-T_R2',
#  'TCGA-D8-A1JM-01A-01-T_R2',
#  'TCGA-BH-A0DP-11A-01-T_R3',
#  'TCGA-A7-A56D-11A-04-T_R10',
#  'TCGA-A7-A13E-01B-03-B_R1',
#  'TCGA-BH-A0HL-01A-01-B_R2',
#  'TCGA-A2-A0CQ-01A-02-T_R2',
#  'TCGA-A8-A09V-01A-01-B_R1',
#  'TCGA-BH-A0HP-01A-01-T_R2',
#  'TCGA-A7-A13D-01A-01-T_R2',
#  'TCGA-D8-A27R-01A-01-T_R2',
#  'TCGA-AR-A5QQ-01A-01-T_R2',
#  'TCGA-GM-A3XL-01A-01-T_R2',
#  'TCGA-BH-A0RX-01A-02-M_R1',
#  'TCGA-EW-A2FW-01A-01-T_R1',
#  'TCGA-BH-A18G-01A-01-T_R3',
#  'TCGA-AN-A0FJ-01A-01-B_R3',
#  'TCGA-BH-A1F6-11B-09-T_R5',
#  'TCGA-BH-A0BF-01A-02-T_R1',
#  'TCGA-BH-A1F8-11B-02-T_R1',
#  'TCGA-A2-A04R-01A-04-T_R1',
#  'TCGA-BH-A0BS-11A-01-B_R3',
#  'TCGA-GM-A2DN-01A-01-T_R2',
#  'TCGA-E9-A1N6-01A-01-T_R2',
#  'TCGA-AQ-A54O-01A-01-T_R1',
#  'TCGA-BH-A0H9-11A-02-B_R4',
#  'TCGA-A1-A0SG-01A-01-T_R1',
#  'TCGA-A8-A09K-01A-01-M_R1',
#  'TCGA-BH-A0BF-01A-02-B_R2',
#  'TCGA-BH-A0DO-11A-02-T_R1',
#  'TCGA-A7-A13F-11A-03-T_R4',
#  'TCGA-A8-A08O-01A-01-B_R1',
#  'TCGA-GM-A2DI-01A-03-T_R1',
#  'TCGA-A2-A25C-01A-01-T_R1',
#  'TCGA-BH-A1EX-11A-01-T_R1',
#  'TCGA-BH-A0HW-01A-01-T_R2',
#  'TCGA-BH-A0DP-11A-01-T_R1',
#  'TCGA-AN-A0FL-01A-01-T_R2',
#  'TCGA-A7-A56D-11A-07-T_R3',
#  'TCGA-A8-A06Y-01A-01-B_R1',
#  'TCGA-E2-A1LG-11A-03-T_R2',
#  'TCGA-A2-A25B-01A-01-T_R1',
#  'TCGA-A7-A13G-01A-01-B_R1',
#  'TCGA-A8-A07G-01A-01-T_R1',
#  'TCGA-BH-A1FC-01A-01-T_R1',
#  'TCGA-E2-A15L-11A-02-T_R1',
#  'TCGA-E2-A1LS-11A-03-T_R2',
#  'TCGA-E9-A1NA-01A-01-T_R1',
#  'TCGA-AC-A23G-11A-01-T_R3',
#  'TCGA-A8-A09R-01A-01-T_R3',
#  'TCGA-GI-A2C8-11A-02-T_R2',
#  'TCGA-BH-A0HW-01A-01-T_R1',
#  'TCGA-E2-A1BD-01A-01-T_R2',
#  'TCGA-E2-A1LH-01A-01-T_R1',
#  'TCGA-E2-A10A-01A-02-B_R5',
#  'TCGA-AN-A0AM-01A-01-B_R2',
#  'TCGA-BH-A0GZ-01A-01-B_R2',
#  'TCGA-EW-A1P5-01A-01-T_R1',
#  'TCGA-AN-A04A-01A-02-B_R2',
#  'TCGA-A7-A56D-01A-01-T_R1',
#  'TCGA-A8-A086-01A-01-T_R2',
#  'TCGA-AO-A1KP-01A-01-T_R2',
#  'TCGA-BH-A6R8-01A-02-T_R2',
#  'TCGA-D8-A1JA-01A-01-T_R1',
#  'TCGA-AR-A24W-01A-01-T_R1',
#  'TCGA-OL-A97C-01A-03-T_R2',
#  'TCGA-BH-A1EN-11A-01-T_R3',
#  'TCGA-E2-A1LG-11A-02-T_R1',
#  'TCGA-D8-A147-01A-01-B_R2',
#  'TCGA-GM-A2DM-01A-01-T_R2',
#  'TCGA-A1-A0SM-01A-01-T_R1',
#  'TCGA-BH-A18G-01A-01-T_R2',
#  'TCGA-HN-A2OB-01A-02-T_R2',
#  'TCGA-BH-A0BO-01A-02-B_R1',
#  'TCGA-A2-A0D1-01A-01-M_R2',
#  'TCGA-BH-A0E1-11A-01-B_R1',
#  'TCGA-BH-A0DD-11A-04-T_R3',
#  'TCGA-BH-A18M-11A-01-T_R2',
#  'TCGA-A2-A0T4-01A-03-B_R2',
#  'TCGA-BH-A0HF-01A-01-B_R4',
#  'TCGA-AO-A12F-01A-01-B_R1',
#  'TCGA-A2-A0D0-01A-01-B_R4',
#  'TCGA-BH-A1EX-11A-01-T_R3',
#  'TCGA-E2-A15F-01A-01-T_R2',
#  'TCGA-A8-A096-01A-01-T_R2',
#  'TCGA-E2-A1BC-11A-02-T_R2',
#  'TCGA-A8-A09K-01A-01-T_R1',
#  'TCGA-A2-A0YF-01A-02-T_R2',
#  'TCGA-E2-A10A-01A-02-B_R2',
#  'TCGA-E2-A1AZ-01A-01-T_R2',
#  'TCGA-BH-A0BG-01A-01-T_R2',
#  'TCGA-E2-A15O-01A-01-T_R2',
#  'TCGA-AR-A24K-01A-01-T_R1',
#  'TCGA-A2-A0T3-01A-02-B_R1',
#  'TCGA-A2-A0SX-01A-01-T_R2',
#  'TCGA-E9-A1NA-11A-01-T_R2',
#  'TCGA-EW-A2FS-01A-01-T_R2',
#  'TCGA-E2-A1L7-01A-01-T_R1',
#  'TCGA-BH-A0H7-11A-01-T_R4',
#  'TCGA-E9-A1N9-11A-06-T_R2',
#  'TCGA-D8-A1X6-01A-01-T_R1',
#  'TCGA-BH-A0DD-01A-03-T_R1',
#  'TCGA-AN-A0FS-01A-01-T_R2',
#  'TCGA-A7-A3J1-01A-01-T_R2',
#  'TCGA-A7-A4SA-11A-03-T_R1',
#  'TCGA-AR-A0TS-01A-01-B_R4',
#  'TCGA-A7-A426-01A-02-T_R1',
#  'TCGA-BH-A0HY-01A-01-T_R1',
#  'TCGA-A2-A0SV-01A-01-B_R2',
#  'TCGA-BH-A0HF-01A-01-B_R2',
#  'TCGA-BH-A1FB-11A-01-T_R1',
#  'TCGA-AC-A3OD-01A-01-T_R1',
#  'TCGA-A2-A0SX-01A-01-T_R1',
#  'TCGA-E9-A1NE-11A-01-T_R3',
#  'TCGA-A8-A07O-01A-01-B_R2',
#  'TCGA-EW-A423-01A-01-T_R1',
#  'TCGA-A8-A0A9-01A-01-B_R2',
#  'TCGA-AC-A3EH-01A-02-T_R2',
#  'TCGA-B6-A40B-01A-01-T_R1',
#  'TCGA-AC-A2BK-01A-01-T_R1',
#  'TCGA-BH-A0W3-01A-01-T_R2',
#  'TCGA-AC-A8OS-01A-01-T_R2',
#  'TCGA-E2-A1LB-11A-02-T_R2',
#  'TCGA-AR-A0TZ-01A-01-B_R2',
#  'TCGA-A1-A0SF-01A-01-M_R1',
#  'TCGA-BH-A0AV-01A-03-M_R1',
#  'TCGA-A8-A09A-01A-01-T_R2',
#  'TCGA-E2-A1L6-01A-01-T_R1',
#  'TCGA-A7-A26J-01B-01-B_R1',
#  'TCGA-A8-A0A9-01A-01-B_R1',
#  'TCGA-A8-A09G-01A-02-B_R1',
#  'TCGA-AO-A0JF-01A-01-B_R4',
#  'TCGA-A8-A09X-01A-01-T_R1',
#  'TCGA-A2-A0SU-01A-01-B_R2',
#  'TCGA-BH-A18J-01A-01-T_R2',
#  'TCGA-A2-A04W-01A-03-T_R1',
#  'TCGA-E2-A14U-01A-01-M_R1',
#  'TCGA-A2-A0D2-01A-02-T_R3',
#  'TCGA-AN-A03X-01A-02-B_R1',
#  'TCGA-AN-A0AL-01A-01-B_R2',
#  'TCGA-A2-A3XS-01A-01-T_R2',
#  'TCGA-BH-A18K-11A-02-T_R1',
#  'TCGA-AO-A03P-01A-01-B_R1',
#  'TCGA-GM-A2DI-01A-03-T_R2',
#  'TCGA-AO-A125-01A-01-B_R2',
#  'TCGA-A2-A0CS-01A-01-T_R1',
#  'TCGA-A7-A4SD-11A-01-T_R2',
#  'TCGA-BH-A0DT-11A-01-T_R2',
#  'TCGA-AO-A0JB-01A-01-B_R2',
#  'TCGA-AR-A0U1-01A-01-T_R2',
#  'TCGA-A2-A0CX-01A-02-T_R1',
#  'TCGA-A8-A07E-01A-01-T_R2',
#  'TCGA-LQ-A4E4-01A-01-T_R3',
#  'TCGA-BH-A1EO-11A-03-T_R1',
#  'TCGA-D8-A1JH-01A-01-T_R1',
#  'TCGA-AO-A0JM-01A-02-T_R2',
#  'TCGA-BH-A0B7-01A-01-B_R2',
#  'TCGA-E2-A1LK-01A-02-T_R1',
#  'TCGA-BH-A0HL-01A-01-T_R2',
#  'TCGA-AC-A3BB-01A-02-T_R2',
#  'TCGA-BH-A18T-01A-01-T_R2',
#  'TCGA-AR-A24H-01A-01-T_R2',
#  'TCGA-AO-A03V-01A-01-T_R2',
#  'TCGA-BH-A1EX-01A-01-T_R1',
#  'TCGA-BH-A18K-11A-01-T_R1',
#  'TCGA-AC-A3QP-01A-01-T_R2',
#  'TCGA-AC-A3BB-01A-02-T_R1',
#  'TCGA-BH-A0H0-01A-01-T_R1',
#  'TCGA-AR-A24H-01A-01-T_R1',
#  'TCGA-EW-A1IY-01A-01-T_R1',
#  'TCGA-A8-A091-01A-01-T_R2',
#  'TCGA-A2-A0EU-01A-02-T_R1',
#  'TCGA-BH-A18G-01A-01-T_R4',
#  'TCGA-A2-A3KD-01A-01-T_R2',
#  'TCGA-A2-A04Y-01A-02-B_R1',
#  'TCGA-E9-A1ND-11A-02-T_R2',
#  'TCGA-BH-A18J-11A-03-T_R2',
#  'TCGA-AN-A0XO-01A-01-B_R1',
#  'TCGA-A8-A08S-01A-01-B_R2',
#  'TCGA-BH-A1FC-11A-03-T_R1',
#  'TCGA-E9-A54X-01A-01-T_R2',
#  'TCGA-OL-A66I-01A-02-T_R1',
#  'TCGA-E2-A572-01A-01-T_R1',
#  'TCGA-BH-A0HF-01A-01-T_R3',
#  'TCGA-OL-A5D8-01A-01-T_R1',
#  'TCGA-AC-A2FK-01A-01-T_R1',
#  'TCGA-A2-A0T3-01A-02-T_R2',
#  'TCGA-E2-A1IL-01A-01-T_R1',
#  'TCGA-BH-A0DV-11A-02-B_R2',
#  'TCGA-AN-A0FY-01A-01-T_R2',
#  'TCGA-AO-A0J5-01A-01-T_R2',
#  'TCGA-D8-A1X8-01A-01-T_R2',
#  'TCGA-E9-A1N5-11A-03-T_R1',
#  'TCGA-BH-A0HX-01A-02-B_R2',
#  'TCGA-A8-A09D-01A-01-B_R3',
#  'TCGA-BH-A0H6-01A-02-B_R2',
#  'TCGA-E9-A54X-01A-01-T_R3',
#  'TCGA-AR-A24X-01A-01-T_R1',
#  'TCGA-BH-A1FC-01A-01-T_R2',
#  'TCGA-BH-A18S-01A-01-T_R1',
#  'TCGA-BH-A0BG-01A-01-B_R3',
#  'TCGA-AR-A1AN-01A-01-T_R2',
#  'TCGA-A8-A08F-01A-01-T_R1',
#  'TCGA-B6-A409-01A-01-T_R1',
#  'TCGA-A8-A06T-01A-01-T_R1',
#  'TCGA-A2-A0T3-01A-02-T_R1',
#  'TCGA-AC-A2FG-01A-01-T_R2',
#  'TCGA-A8-A08I-01A-01-B_R1',
#  'TCGA-A7-A4SB-01A-02-T_R4',
#  'TCGA-A8-A07J-01A-02-B_R2',
#  'TCGA-AO-A129-01A-02-B_R1',
#  'TCGA-BH-A0HL-01A-01-B_R1',
#  'TCGA-AN-A0FN-01A-01-B_R2',
#  'TCGA-A2-A0T0-01A-02-B_R1',
#  'TCGA-AN-A0AR-01A-01-T_R1',
#  'TCGA-E2-A56Z-01A-01-T_R3',
#  'TCGA-E2-A1II-11A-02-T_R2',
#  'TCGA-BH-A1FC-11A-01-T_R4',
#  'TCGA-AN-A0FJ-01A-01-T_R1',
#  'TCGA-AQ-A54N-01A-01-T_R2',
#  'TCGA-E2-A9RU-01A-01-T_R3',
#  'TCGA-BH-A0GZ-01A-01-B_R1',
#  'TCGA-AO-A0J7-01A-01-T_R1',
#  'TCGA-AN-A0FS-01A-01-T_R1',
#  'TCGA-B6-A1KC-01B-01-T_R2',
#  'TCGA-AR-A0U1-01A-01-M_R2',
#  'TCGA-A2-A3XW-01A-01-T_R2',
#  'TCGA-EW-A1PG-01A-01-T_R1',
#  'TCGA-A2-A4RY-01A-03-T_R1',
#  'TCGA-BH-A0H3-11A-01-T_R1',
#  'TCGA-BH-A18U-11A-02-T_R1',
#  'TCGA-EW-A1P4-01A-02-T_R2',
#  'TCGA-BH-A0B9-01A-01-T_R1',
#  'TCGA-A2-A0D2-01A-02-T_R4',
#  'TCGA-AN-A049-01A-01-B_R2',
#  'TCGA-AO-A0J5-01A-01-B_R1',
#  'TCGA-A7-A426-01A-02-T_R2',
#  'TCGA-A2-A0CM-01A-03-B_R3',
#  'TCGA-BH-A0DT-01A-02-T_R1',
#  'TCGA-E9-A1N6-01A-01-T_R1',
#  'TCGA-BH-A0HL-01A-01-T_R3',
#  'TCGA-E2-A1B0-01A-01-T_R2',
#  'TCGA-BH-A0DD-11A-04-T_R2',
#  'TCGA-BH-A0B0-01A-02-B_R2',
#  'TCGA-AN-A04A-01A-01-B_R1',
#  'TCGA-E2-A1LB-11A-01-T_R1',
#  'TCGA-BH-A0H7-11A-01-T_R2',
#  'TCGA-A7-A5ZW-01A-01-T_R1',
#  'TCGA-E2-A2P5-01A-01-T_R1',
#  'TCGA-A8-A07P-01A-01-T_R1',
#  'TCGA-BH-A0B4-01A-01-B_R1',
#  'TCGA-BH-A1EW-11B-01-T_R1',
#  'TCGA-E2-A1LE-11A-01-T_R2',
#  'TCGA-BH-A0WA-01A-01-T_R2',
#  'TCGA-LL-A6FQ-01A-01-T_R1',
#  'TCGA-BH-A18U-11A-02-T_R2',
#  'TCGA-A2-A3Y0-01A-01-T_R1',
#  'TCGA-E2-A1LB-11A-02-T_R1',
#  'TCGA-BH-A0BS-01A-01-B_R2',
#  'TCGA-A2-A0D1-01A-01-T_R3',
#  'TCGA-E9-A1N4-11A-02-T_R1',
#  'TCGA-GM-A2D9-11A-02-T_R1',
#  'TCGA-AC-A2QI-01A-01-T_R1',
#  'TCGA-BH-A0HO-01A-01-B_R1',
#  'TCGA-E9-A1NH-11A-02-T_R1',
#  'TCGA-E2-A1IK-01A-01-T_R1',
#  'TCGA-BH-A0DH-11A-03-T_R1',
#  'TCGA-AR-A1AH-01A-01-T_R1',
#  'TCGA-GM-A3XL-01A-01-T_R5',
#  'TCGA-A8-A09N-01A-01-B_R2',
#  'TCGA-BH-A18Q-11A-02-T_R5',
#  'TCGA-E2-A15I-11A-01-T_R2',
#  'TCGA-BH-A0BF-11A-02-T_R3',
#  'TCGA-A2-A0SV-01A-01-T_R2',
#  'TCGA-BH-A18N-11A-01-T_R1',
#  'TCGA-A8-A08B-01A-01-M_R1',
#  'TCGA-GM-A2DB-01A-03-T_R2',
#  'TCGA-AO-A0JB-01A-01-B_R1',
#  'TCGA-AR-A0TQ-01A-01-B_R1',
#  'TCGA-MS-A51U-01A-03-T_R2',
#  'TCGA-E2-A109-01A-01-T_R2',
#  'TCGA-BH-A0HB-01A-01-M_R1',
#  'TCGA-A2-A0CP-01A-01-T_R1',
#  'TCGA-E2-A1LK-11A-01-T_R1',
#  'TCGA-BH-A0DP-11A-01-B_R3',
#  'TCGA-E2-A14Y-01A-02-T_R2',
#  'TCGA-A7-A5ZX-11A-05-T_R2',
#  'TCGA-E9-A1NE-11A-04-T_R2',
#  'TCGA-E2-A1IF-11A-02-T_R3',
#  'TCGA-AN-A0AK-01A-02-T_R1',
#  'TCGA-A2-A0CM-01A-03-B_R1',
#  'TCGA-AO-A03R-01A-02-B_R1',
#  'TCGA-OL-A5RZ-01A-01-T_R2',
#  'TCGA-A2-A1FX-01A-01-T_R1',
#  'TCGA-D8-A146-01A-03-T_R3',
#  'TCGA-LD-A7W5-01A-02-T_R2',
#  'TCGA-AR-A24Q-01A-01-T_R2',
#  'TCGA-AO-A03P-01A-01-T_R2',
#  'TCGA-BH-A0B1-01A-01-B_R2',
#  'TCGA-A8-A09Z-01A-01-T_R2',
#  'TCGA-A2-A25F-01A-01-T_R3',
#  'TCGA-A2-A04V-01A-02-M_R1',
#  'TCGA-BH-A0BF-01A-02-B_R5',
#  'TCGA-EW-A1IW-01A-01-T_R2',
#  'TCGA-S3-AA12-01A-01-T_R2',
#  'TCGA-AC-A3QQ-01A-01-T_R1',
#  'TCGA-BH-A0C3-11A-02-T_R2',
#  'TCGA-BH-A0DK-11A-01-T_R2',
#  'TCGA-D8-A1X6-01A-01-T_R2',
#  'TCGA-A2-A0EV-01A-01-T_R2',
#  'TCGA-A8-A07F-01A-01-T_R1',
#  'TCGA-A2-A0CT-01A-02-B_R4',
#  'TCGA-E2-A1LG-01A-02-T_R2',
#  'TCGA-AN-A0G0-01A-01-T_R3',
#  'TCGA-BH-A0B0-01A-02-B_R3',
#  'TCGA-AO-A0J5-01A-01-T_R1',
#  'TCGA-A2-A0YI-01A-03-T_R1',
#  'TCGA-AC-A62Y-01A-01-T_R1',
#  'TCGA-AO-A124-01A-01-B_R1',
#  'TCGA-AC-A3EH-01A-02-T_R1',
#  'TCGA-A8-A08X-01A-02-B_R2',
#  'TCGA-BH-A1FG-11A-02-T_R2',
#  'TCGA-E2-A109-01A-01-T_R1',
#  'TCGA-A8-A094-01A-01-T_R1',
#  'TCGA-A8-A0AD-01A-01-B_R1',
#  'TCGA-BH-A0BO-01A-01-B_R6',
#  'TCGA-A8-A08P-01A-01-T_R2',
#  'TCGA-A2-A0YL-01A-02-T_R1',
#  'TCGA-E2-A1LI-11A-02-T_R1',
#  'TCGA-E9-A1N5-11A-01-T_R1',
#  'TCGA-E2-A107-01A-01-T_R2',
#  'TCGA-E2-A1IJ-01A-01-T_R2',
#  'TCGA-EW-A1P4-01A-02-T_R1',
#  'TCGA-A2-A0T1-01A-02-B_R2',
#  'TCGA-E9-A1NA-11A-03-T_R2',
#  'TCGA-BH-A18L-11A-04-T_R1',
#  'TCGA-AN-A0FT-01A-01-T_R3',
#  'TCGA-E9-A1N5-11A-02-T_R2',
#  'TCGA-A8-A09Z-01A-01-T_R3',
#  'TCGA-E2-A572-01A-01-T_R2',
#  'TCGA-E2-A1IU-11A-06-T_R2',
#  'TCGA-A2-A0CP-01A-01-B_R1',
#  'TCGA-E2-A1LH-11A-02-T_R2',
#  'TCGA-AN-A0FZ-01A-01-T_R2',
#  'TCGA-BH-A0AU-01A-01-B_R1',
#  'TCGA-A2-A04W-01A-03-B_R2',
#  'TCGA-BH-A0W7-01A-01-B_R1',
#  'TCGA-E2-A1LE-11A-02-T_R1',
#  'TCGA-EW-A423-01A-01-T_R2',
#  'TCGA-S3-AA11-01A-03-T_R1',
#  'TCGA-AO-A0J9-01A-01-T_R1',
#  'TCGA-E2-A1L7-11A-03-T_R2',
#  'TCGA-BH-A0HQ-01A-01-T_R1',
#  'TCGA-A8-A06T-01A-01-B_R1',
#  'TCGA-EW-A6S9-01A-02-T_R2',
#  'TCGA-A2-A0CT-01A-03-B_R3',
#  'TCGA-BH-A0H9-01A-01-T_R1',
#  'TCGA-AC-A3QQ-01A-01-T_R4',
#  'TCGA-A2-A0EQ-01A-01-B_R1',
#  'TCGA-BH-A0E0-01A-01-T_R1',
#  'TCGA-BH-A0DG-01A-02-B_R3',
#  'TCGA-E2-A15P-01A-01-T_R2',
#  'TCGA-D8-A13Z-01A-01-T_R1',
#  'TCGA-A2-A0T7-01A-02-T_R1',
#  'TCGA-AO-A03P-01A-01-T_R1',
#  'TCGA-AR-A1AK-01A-02-T_R2',
#  'TCGA-EW-A1OV-01A-01-T_R1',
#  'TCGA-BH-A0AV-01A-03-B_R1',
#  'TCGA-BH-A18F-11A-01-T_R2',
#  'TCGA-A7-A13G-11A-05-T_R5',
#  'TCGA-GM-A3NY-01A-01-T_R3',
#  'TCGA-A2-A0EM-01A-01-B_R4',
#  'TCGA-AR-A2LR-01A-01-T_R2',
#  'TCGA-AQ-A0Y5-01A-01-B_R1',
#  'TCGA-BH-A0BQ-11A-03-T_R3',
#  'TCGA-A7-A26J-01A-01-T_R1',
#  'TCGA-A2-A0SW-01A-01-B_R1',
#  'TCGA-AC-A23H-11A-01-T_R1',
#  'TCGA-LL-A441-01A-01-T_R1',
#  'TCGA-AO-A03U-01B-02-B_R2',
#  'TCGA-A1-A0SI-01A-01-T_R1',
#  'TCGA-LL-A8F5-01A-01-T_R2',
#  'TCGA-BH-A18L-11A-02-T_R1',
#  'TCGA-BH-A0BA-01A-01-B_R2',
#  'TCGA-GI-A2C8-01A-01-T_R1',
#  'TCGA-AO-A126-01A-01-B_R1',
#  'TCGA-BH-A0B1-01A-01-T_R2',
#  'TCGA-OL-A5RY-01A-02-T_R2',
#  'TCGA-E2-A14T-01A-01-T_R1',
#  'TCGA-BH-A0HY-01A-01-T_R2',
#  'TCGA-AN-A0AJ-01A-01-T_R1',
#  'TCGA-AO-A0JI-01A-02-T_R3',
#  'TCGA-BH-A1EN-11A-01-T_R7',
#  'TCGA-BH-A0DH-11A-03-T_R3',
#  'TCGA-E2-A1IO-11A-01-T_R1',
#  'TCGA-A7-A26F-01A-02-T_R1',
#  'TCGA-E2-A153-11A-03-T_R2',
#  'TCGA-A2-A0YK-01A-02-T_R2',
#  'TCGA-BH-A0WA-01A-01-T_R1',
#  'TCGA-A8-A09Z-01A-01-B_R1',
#  'TCGA-A1-A0SK-01A-01-B_R1',
#  'TCGA-A1-A0SQ-01A-02-B_R2',
#  'TCGA-AO-A12D-01A-01-B_R2',
#  'TCGA-D8-A1J9-01A-01-T_R2',
#  'TCGA-A7-A0DA-01A-03-T_R4',
#  'TCGA-A2-A0EY-01A-01-T_R2',
#  'TCGA-BH-A0DD-11A-02-T_R2',
#  'TCGA-A8-A08H-01A-02-B_R1',
#  'TCGA-AQ-A0Y5-01A-01-B_R2',
#  'TCGA-BH-AB28-11A-01-T_R2',
#  'TCGA-B6-A402-01A-01-T_R1',
#  'TCGA-BH-A0BM-01A-01-T_R2',
#  'TCGA-D8-A1J8-01A-01-T_R1',
#  'TCGA-AN-A0XN-01A-02-T_R1',
#  'TCGA-AO-A12G-01A-01-T_R2',
#  'TCGA-E2-A1IN-01A-01-T_R1',
#  'TCGA-A1-A0SQ-01A-02-T_R2',
#  'TCGA-E9-A1N6-11A-01-T_R1',
#  'TCGA-BH-A18J-11A-01-T_R1',
#  'TCGA-BH-A18J-11A-01-T_R2',
#  'TCGA-A2-A259-01A-01-T_R1',
#  'TCGA-AO-A0J3-01A-01-T_R1',
#  'TCGA-A2-A04V-01A-02-B_R3',
#  'TCGA-E2-A15C-01A-03-T_R2',
#  'TCGA-D8-A147-01A-01-T_R2',
#  'TCGA-D8-A27N-01A-01-T_R2',
#  'TCGA-BH-A0HX-01A-02-T_R1',
#  'TCGA-E2-A1LK-11A-01-T_R2',
#  'TCGA-AR-A0U3-01A-01-T_R2',
#  'TCGA-AR-A0TV-01A-02-T_R1',
#  'TCGA-BH-A0BL-01A-01-T_R2',
#  'TCGA-A2-A0CU-01A-01-B_R2',
#  'TCGA-AN-A0XL-01A-01-B_R1',
#  'TCGA-A8-A09M-01A-01-B_R3',
#  'TCGA-BH-A0BF-11A-01-T_R1',
#  'TCGA-E9-A1NE-11A-02-T_R2',
#  'TCGA-AN-A0FW-01A-01-B_R6',
#  'TCGA-AQ-A04L-01B-02-T_R1',
#  'TCGA-BH-A1F8-01A-01-T_R1',
#  'TCGA-A8-A07I-01A-01-B_R3',
#  'TCGA-E2-A15M-01A-01-T_R2',
#  'TCGA-A2-A0D0-01A-01-B_R2',
#  'TCGA-BH-A0BM-11A-01-T_R3',
#  'TCGA-A1-A0SF-01A-01-M_R2',
#  'TCGA-A7-A4SA-11A-02-T_R3',
#  'TCGA-E2-A153-11A-02-T_R1',
#  'TCGA-AN-A0FK-01A-01-T_R1',
#  'TCGA-A8-A06P-01A-01-T_R2',
#  'TCGA-AO-A0J8-01A-02-T_R1',
#  'TCGA-AO-A12A-01A-02-B_R1',
#  'TCGA-A8-A085-01A-01-B_R2',
#  'TCGA-AR-A24R-01A-01-T_R1',
#  'TCGA-AN-A0FT-01A-01-B_R2',
#  'TCGA-BH-A0EA-01A-01-M_R3',
#  'TCGA-D8-A1X5-01A-01-T_R1',
#  'TCGA-A8-A07E-01A-01-T_R1',
#  'TCGA-AC-A2FF-01A-01-T_R2',
#  'TCGA-AN-A0FL-01A-01-T_R1',
#  'TCGA-AO-A03U-01B-02-T_R2',
#  'TCGA-D8-A1XV-01A-01-T_R2',
#  'TCGA-E2-A1IF-11A-02-T_R2',
#  'TCGA-A8-A075-01A-01-B_R1',
#  'TCGA-AO-A0JF-01A-01-B_R3',
#  'TCGA-E2-A14P-01A-03-T_R2',
#  'TCGA-E9-A1NG-11A-04-T_R4',
#  'TCGA-LL-A442-01A-01-T_R1',
#  'TCGA-BH-A0EE-01A-01-T_R3',
#  'TCGA-E2-A1LE-01A-01-T_R2',
#  'TCGA-AO-A03R-01A-01-B_R2',
#  'TCGA-E2-A108-01A-01-T_R2',
#  'TCGA-AN-A0AM-01A-01-B_R1',
#  'TCGA-AC-A2QJ-01A-01-T_R1',
#  'TCGA-AO-A12B-01A-01-T_R1',
#  'TCGA-AN-A0FV-01A-01-T_R1',
#  'TCGA-A7-A26E-01A-01-T_R1',
#  'TCGA-AC-A2FO-01A-01-T_R1',
#  'TCGA-AR-A24Q-01A-01-T_R1',
#  'TCGA-BH-A5IZ-01A-01-T_R1',
#  'TCGA-E2-A56Z-01A-01-T_R1',
#  'TCGA-AR-A0TW-01A-01-T_R1',
#  'TCGA-E2-A14W-01A-01-T_R1',
#  'TCGA-A8-A086-01A-01-T_R1',
#  'TCGA-A2-A0D2-01A-02-T_R1',
#  'TCGA-BH-A0DV-01A-02-T_R1',
#  'TCGA-E2-A1IU-01A-01-T_R2',
#  'TCGA-BH-A1EV-11A-01-T_R1',
#  'TCGA-A8-A08R-01A-01-M_R2',
#  'TCGA-A7-A0CD-01A-01-T_R3',
#  'TCGA-A1-A0SP-01A-01-B_R1',
#  'TCGA-A1-A0SQ-01A-02-T_R1',
#  'TCGA-AN-A0XN-01A-02-T_R2',
#  'TCGA-BH-A0BW-01A-01-B_R2',
#  'TCGA-LL-A8F5-01A-01-T_R1',
#  'TCGA-BH-A0DH-01A-01-B_R2',
#  'TCGA-E2-A1LI-11A-02-T_R2',
#  'TCGA-AR-A24S-01A-01-T_R1',
#  'TCGA-A8-A07P-01A-01-B_R2',
#  'TCGA-AR-A0TR-01A-01-B_R2',
#  'TCGA-A7-A4SE-11A-01-T_R2',
#  'TCGA-A8-A079-01A-02-M_R2',
#  'TCGA-BH-A18J-11A-02-T_R3',
#  'TCGA-E9-A3X8-01A-03-T_R2',
#  'TCGA-BH-A0DZ-11A-02-B_R2',
#  'TCGA-BH-A0BA-11A-02-T_R2',
#  'TCGA-A7-A13G-01A-01-T_R1',
#  'TCGA-A8-A096-01A-01-T_R1',
#  'TCGA-AO-A03M-01B-01-B_R1',
#  'TCGA-A2-A4S0-01A-02-T_R2',
#  'TCGA-A8-A07R-01A-01-B_R1',
#  'TCGA-A8-A094-01A-01-T_R2',
#  'TCGA-AR-A1AH-01A-01-T_R2',
#  'TCGA-E9-A1NG-01A-02-T_R2',
#  'TCGA-BH-A0HP-01A-01-T_R1',
#  'TCGA-BH-A18N-11A-02-T_R1',
#  'TCGA-BH-A0DT-11A-01-T_R1',
#  'TCGA-A2-A0T1-01A-02-B_R1',
#  'TCGA-BH-A0HK-11A-01-T_R1',
#  'TCGA-AN-A0XT-01A-01-B_R1',
#  'TCGA-BH-A1FD-11B-01-T_R1',
#  'TCGA-A8-A08F-01A-01-B_R2',
#  'TCGA-AN-A0AK-01A-02-T_R2',
#  'TCGA-BH-A0H5-01A-02-T_R2',
#  'TCGA-E2-A15J-01A-01-T_R2',
#  'TCGA-A1-A0SM-01A-01-T_R2',
#  'TCGA-A7-A13F-11A-03-T_R2',
#  'TCGA-AO-A03L-01A-04-B_R2',
#  'TCGA-AO-A1KP-01A-01-T_R1',
#  'TCGA-A2-A0YJ-01A-01-B_R2',
#  'TCGA-A8-A09X-01A-01-B_R2',
#  'TCGA-A7-A4SC-01A-01-T_R2',
#  'TCGA-A8-A07G-01A-01-T_R2',
#  'TCGA-BH-A0B0-01A-02-T_R1',
#  'TCGA-AO-A0JA-01A-01-B_R2',
#  'TCGA-A8-A075-01A-01-B_R2',
#  'TCGA-E2-A10A-01A-02-T_R2',
#  'TCGA-BH-A0DI-11A-01-T_R2',
#  'TCGA-BH-A0DQ-01A-01-M_R2',
#  'TCGA-MS-A51U-01A-03-T_R1',
#  'TCGA-BH-A18J-11A-03-T_R1',
#  'TCGA-A1-A0SP-01A-01-T_R1',
#  'TCGA-S3-AA14-01A-01-T_R2',
#  'TCGA-A8-A07R-01A-02-B_R2',
#  'TCGA-OL-A6VR-01A-03-T_R2',
#  'TCGA-E2-A156-01A-01-T_R2',
#  'TCGA-E9-A1N4-11A-02-T_R2',
#  'TCGA-BH-A0BJ-01A-01-B_R2',
#  'TCGA-BH-A1EX-11A-01-T_R4',
#  'TCGA-A7-A13G-11A-05-T_R2',
#  'TCGA-AN-A0FK-01A-01-B_R2',
#  'TCGA-E2-A1LG-01A-02-T_R1',
#  'TCGA-A1-A0SE-01A-01-B_R2',
#  'TCGA-A8-A09W-01A-01-T_R3',
#  'TCGA-BH-A1FD-11A-01-T_R2',
#  'TCGA-LD-A7W6-01A-08-T_R2',
#  'TCGA-E9-A1NG-11A-04-T_R1',
#  'TCGA-A2-A0YG-01A-02-B_R2',
#  'TCGA-A2-A4RX-01A-01-T_R1',
#  'TCGA-LQ-A4E4-01A-01-T_R2',
#  'TCGA-OL-A5RY-01A-02-T_R1',
#  'TCGA-D8-A143-01A-01-T_R2',
#  'TCGA-AR-A0TS-01A-01-B_R2',
#  'TCGA-AO-A03U-01B-02-B_R1',
#  'TCGA-BH-A0DO-11A-02-T_R2',
#  'TCGA-AN-A0FX-01A-01-T_R2',
#  'TCGA-BH-A1F5-11A-03-T_R2',
#  'TCGA-D8-A146-01A-03-T_R2',
#  'TCGA-D8-A1JC-01A-01-T_R1',
#  'TCGA-BH-A0B7-11A-02-T_R2',
#  'TCGA-A8-A06Z-01A-01-B_R2',
#  'TCGA-AO-A0JB-01A-01-T_R1',
#  'TCGA-E2-A1BD-01A-01-T_R1',
#  'TCGA-BH-A0E1-01A-01-B_R3',
#  'TCGA-D8-A4Z1-01A-02-T_R2',
#  'TCGA-A8-A09G-01A-02-B_R2',
#  'TCGA-E9-A1NH-11A-01-T_R2',
#  'TCGA-A2-A0EM-01A-01-B_R5',
#  'TCGA-AQ-A04L-01B-02-T_R2',
#  'TCGA-E2-A1B5-11A-02-T_R1',
#  'TCGA-AR-A24U-01A-01-T_R1',
#  'TCGA-AC-A8OS-01A-01-T_R1',
#  'TCGA-AN-A0G0-01A-01-B_R1',
#  'TCGA-A2-A0EY-01A-01-B_R2',
#  'TCGA-A8-A07B-01A-01-B_R1',
#  'TCGA-A8-A07S-01A-01-T_R1',
#  'TCGA-AR-A0U3-01A-01-T_R1',
#  'TCGA-BH-A0BQ-01A-02-B_R1',
#  'TCGA-BH-A1FG-11A-02-T_R1',
#  'TCGA-A8-A07P-01A-01-B_R1',
#  'TCGA-AC-A62Y-01A-01-T_R6',
#  'TCGA-GM-A2DM-01A-01-T_R1',
#  'TCGA-A2-A0D0-01A-01-B_R3',
#  'TCGA-LL-A6FP-01A-01-T_R2',
#  'TCGA-A2-A3KD-01A-01-T_R1',
#  'TCGA-A8-A0A2-01A-01-B_R1',
#  'TCGA-AO-A03V-01A-01-T_R1',
#  'TCGA-E2-A1B1-01A-02-T_R1',
#  'TCGA-AC-A23H-11A-01-T_R2',
#  'TCGA-E9-A1N5-11A-01-T_R2',
#  'TCGA-E2-A1LI-11A-01-T_R1',
#  'TCGA-BH-A0B5-01A-01-T_R1',
#  'TCGA-A8-A06Y-01A-02-B_R1',
#  'TCGA-AO-A0JM-01A-02-T_R1',
#  'TCGA-A2-A0YL-01A-02-B_R1',
#  'TCGA-A8-A08F-01A-01-B_R1',
#  'TCGA-BH-A0B3-11B-02-T_R3',
#  'TCGA-E2-A15R-01A-01-T_R1',
#  'TCGA-A2-A3XV-01A-02-T_R1',
#  'TCGA-AN-A0FV-01A-01-B_R1',
#  'TCGA-AR-A0TT-01A-03-T_R2',
#  'TCGA-AR-A0TZ-01A-01-T_R1',
#  'TCGA-BH-A0BP-01A-01-T_R1',
#  'TCGA-E2-A56Z-01A-01-T_R2',
#  'TCGA-A2-A0CU-01A-01-T_R3',
#  'TCGA-A2-A0YT-01A-01-B_R2',
#  'TCGA-BH-AB28-11A-01-T_R1',
#  'TCGA-A8-A08J-01A-01-T_R2',
#  'TCGA-AO-A1KT-01A-01-T_R1',
#  'TCGA-AO-A0JA-01A-01-T_R2',
#  'TCGA-BH-A0HK-01A-01-B_R2',
#  'TCGA-BH-A0BS-11A-01-B_R1',
#  'TCGA-A2-A0EO-01A-01-M_R4',
#  'TCGA-E2-A1IG-11A-01-T_R1',
#  'TCGA-A2-A0CR-01A-01-B_R3',
#  'TCGA-A2-A0SU-01A-01-B_R1',
#  'TCGA-A8-A06Q-01A-01-B_R2',
#  'TCGA-AR-A0TX-01A-01-B_R1',
#  'TCGA-A2-A0T4-01A-03-B_R1',
#  'TCGA-AO-A0J8-01A-02-T_R2',
#  'TCGA-AO-A126-01A-01-B_R2',
#  'TCGA-BH-A0E0-01A-01-B_R1',
#  'TCGA-BH-A0BM-11A-01-T_R2',
#  'TCGA-E2-A1IE-01A-01-T_R1',
#  'TCGA-BH-A0DK-01A-02-T_R1',
#  'TCGA-BH-A0C0-11A-02-T_R1',
#  'TCGA-A2-A25F-01A-01-T_R1',
#  'TCGA-AN-A0G0-01A-01-B_R2',
#  'TCGA-BH-A0DS-01A-01-B_R1',
#  'TCGA-BH-A1ET-11A-01-T_R1',
#  'TCGA-BH-AB28-11A-02-T_R1',
#  'TCGA-AN-A0FD-01A-01-B_R2',
#  'TCGA-A8-A0A2-01A-01-T_R1',
#  'TCGA-D8-A27T-01A-01-T_R1',
#  'TCGA-AO-A0JC-01A-01-T_R3',
#  'TCGA-BH-A0DP-11A-01-T_R2',
#  'TCGA-A1-A0SJ-01A-01-T_R2',
#  'TCGA-A8-A076-01A-02-B_R1',
#  'TCGA-A2-A4RW-01A-02-T_R2',
#  'TCGA-EW-A1PG-01A-01-T_R2',
#  'TCGA-AO-A0JC-01A-01-T_R1',
#  'TCGA-A8-A08O-01A-01-B_R2',
#  'TCGA-BH-A0HO-01A-01-B_R3',
#  'TCGA-E2-A10A-01A-02-B_R3',
#  'TCGA-EW-A6SB-01A-01-T_R1',
#  'TCGA-BH-A0RX-01A-02-T_R1',
#  'TCGA-AN-A0XV-01A-01-T_R2',
#  'TCGA-A8-A07I-01A-01-B_R1',
#  'TCGA-BH-A18T-01A-01-T_R1',
#  'TCGA-A2-A0D2-01A-02-B_R2',
#  'TCGA-A2-A3XW-01A-01-T_R1',
#  'TCGA-A8-A09R-01A-01-B_R1',
#  'TCGA-BH-A1F6-11B-07-T_R5',
#  'TCGA-AO-A0J7-01A-01-T_R2',
#  'TCGA-AR-A5QQ-01A-01-T_R1',
#  'TCGA-BH-A0E1-01A-01-T_R1',
#  'TCGA-AO-A0JI-01A-02-T_R2',
#  'TCGA-BH-A0B9-01A-01-B_R2',
#  'TCGA-BH-A0BP-01A-01-B_R1',
#  'TCGA-BH-A0BZ-01A-03-B_R2',
#  'TCGA-LL-A440-01A-01-T_R2',
#  'TCGA-EW-A1J3-01A-01-T_R1',
#  'TCGA-BH-A0DO-11A-01-T_R1',
#  'TCGA-A2-A0EV-01A-01-B_R2',
#  'TCGA-E9-A1NA-11A-03-T_R1',
#  'TCGA-BH-A1EY-11A-02-T_R1',
#  'TCGA-A8-A08R-01A-01-M_R1',
#  'TCGA-A2-A0YD-01A-01-B_R2',
#  'TCGA-S3-AA17-01A-01-T_R2',
#  'TCGA-A7-A5ZX-11A-05-T_R3',
#  'TCGA-A2-A3Y0-01A-01-T_R2',
#  'TCGA-AC-A3HN-01A-01-T_R1',
#  'TCGA-AN-A0FX-01A-01-T_R3',
#  'TCGA-E2-A1II-11A-02-T_R4',
#  'TCGA-BH-A0AY-01A-02-T_R1',
#  'TCGA-BH-A42T-01A-01-T_R1',
#  'TCGA-AC-A2QH-01B-03-B_R1',
#  'TCGA-A2-A0YH-01A-01-T_R1',
#  'TCGA-AO-A12G-01A-01-B_R2',
#  'TCGA-BH-A0DL-11A-01-T_R2',
#  'TCGA-A8-A06N-01A-01-T_R2',
#  'TCGA-BH-A0DG-01A-02-B_R2',
#  'TCGA-D8-A1Y0-01A-01-T_R2',
#  'TCGA-BH-A0B0-01A-02-B_R1',
#  'TCGA-BH-A0HF-01A-01-B_R3',
#  'TCGA-BH-A1EW-11B-03-T_R2',
#  'TCGA-A8-A091-01A-01-T_R1',
#  'TCGA-D8-A1X8-01A-01-T_R1',
#  'TCGA-E2-A153-11A-03-T_R1',
#  'TCGA-AN-A0AT-01A-01-B_R1',
#  'TCGA-E2-A1L6-01A-01-T_R2',
#  'TCGA-AN-A049-01A-01-B_R1',
#  'TCGA-BH-A1EU-11A-02-T_R2',
#  'TCGA-GM-A3XL-01A-01-T_R3',
#  'TCGA-AN-A0FW-01A-01-B_R5',
#  'TCGA-BH-A0EI-01A-01-B_R1',
#  'TCGA-A8-A07I-01A-01-T_R1',
#  'TCGA-AO-A0JI-01A-02-B_R3',
#  ...]

# %%
np.sum(np.array([1, 2, 3]) == np.array([1, 3, 3]))
# Out:
# 2

# %%
train_dataset = TCGABags(train_df, ['hr+her2-', 'hr-', 'hr+her2+'])
test_dataset = TCGABags(test_df, ['hr+her2-', 'hr-', 'hr+her2+'])
train_dl = DataLoader(train_dataset, batch_size=1)
test_dl = DataLoader(test_dataset, batch_size=1)
instance_loss_fn = nn.CrossEntropyLoss()
global_loss_fn = nn.CrossEntropyLoss()
model = CLAM_SB(n_classes=3, instance_loss_fn=instance_loss_fn).to('cpu')
optimizer = optim.Adam(model.parameters(), lr=1e-3,
                       betas=(0.9, 0.999))

device = 'cuda:0'
bag_weight = 0.7

timm_model = TimmCNNEncoder().to(device)
model = model.to(device)
train_losses = []
valid_losses = []
valid_accs = []
for epoch in tqdm(range(15)):
    train_loss = 0.
    val_loss = 0.
    train_error = 0.
    train_inst_loss = 0.
    val_inst_loss = 0
    model.train()
    for i, (data, label) in enumerate(train_dl):
        data, label = data.to(device), label.to(device)
        logits, Y_prob, Y_hat, _, instance_dict = model(timm_model(data[0]), label=label, instance_eval=True)
        loss = global_loss_fn(logits, label)
        loss_value = loss.item()

        instance_loss = instance_dict['instance_loss']
        instance_loss_value = instance_loss.item()
        train_inst_loss += instance_loss_value
        
        total_loss = bag_weight * loss + (1-bag_weight) * instance_loss 

        inst_preds = instance_dict['inst_preds']
        inst_labels = instance_dict['inst_labels']

        train_loss += loss_value
        
        total_loss.backward()
        # step
        optimizer.step()
        optimizer.zero_grad()
    
    train_losses.append(train_loss/len(train_dl))
    actual_labels = []
    predicted_labels = []
    model.eval()
    with torch.inference_mode():
        for batch_idx, (data, label) in enumerate(test_dl):
            data, label = data.to(device), label.to(device)      
            logits, Y_prob, Y_hat, _, instance_dict = model(timm_model(data[0]), label=label, instance_eval=True)
            
            actual_labels.append(label.cpu()[0])
            predicted_labels.append(Y_hat.cpu()[0][0])
            loss = global_loss_fn(logits, label)

            val_loss += loss.item()

            instance_loss = instance_dict['instance_loss']
            
            instance_loss_value = instance_loss.item()
            val_inst_loss += instance_loss_value
        
        correct_sum = np.sum(np.array(predicted_labels) == np.array(actual_labels))
        valid_accs.append(correct_sum/len(predicted_labels))
        valid_losses.append(val_loss/len(test_dl))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 train_dataset = TCGABags(train_df, ['hr+her2-', 'hr-', 'hr+her2+'])
#       2 test_dataset = TCGABags(test_df, ['hr+her2-', 'hr-', 'hr+her2+'])
#       3 train_dl = DataLoader(train_dataset, batch_size=1)
#
# NameError: name 'TCGABags' is not defined

# %%
dl = DataLoader(TCGABags(df, ['hr+her2-', 'hr-', 'hr+her2+']), batch_size=1)
emb_model = Attention().to('cuda')
optimizer = optim.Adam(emb_model.parameters(), lr=1e-3,
                       betas=(0.9, 0.999))

emb_model.train()
train_loss = 0.
train_error = 0.
for i, (data, bag_label) in enumerate(dl):
    print(data.shape)
    bag_label = bag_label.to('cuda')
    p = data.permute(0, 1, 4, 2, 3).to('cuda')
    optimizer.zero_grad()
    # calculate loss and metrics
    loss, _ = emb_model.calculate_objective(p, bag_label)
    train_loss += loss.data[0]
    print(bag_label)
    error, _ = emb_model.calculate_classification_error(p, bag_label)
    train_error += error
    
    loss.backward()
        # step
    optimizer.step()
    # backward pass
# Out:
# torch.Size([1, 10, 3, 224, 224])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[64], line 15
#      13 optimizer.zero_grad()
#      14 # calculate loss and metrics
# ---> 15 loss, _ = emb_model.calculate_objective(p, bag_label)
#      16 train_loss += loss.data[0]
#      17 print(bag_label)
#
# Cell In[7], line 68, in Attention.calculate_objective(self, X, Y)
#      66 def calculate_objective(self, X, Y):
#      67     Y = Y.float()
# ---> 68     Y_prob, _, A = self.forward(X)
#      69     Y_prob = torch.clamp(Y_prob, min=1e-5, max=1. - 1e-5)
#      70     neg_log_likelihood = -1. * \
#      71         (Y * torch.log(Y_prob) + (1. - Y) *
#      72          torch.log(1. - Y_prob))  # negative log bernoulli
#
# Cell In[7], line 41, in Attention.forward(self, x)
#      39 def forward(self, x):
#      40     x = x.squeeze(0)
# ---> 41     H = self.feature_extractor_part1(x)
#      42     print(H.shape)
#      43     H = H.reshape(-1, 50 * 53 * 53)
#
# File ~/mgr/env/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/mgr/env/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/mgr/env/lib/python3.10/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/mgr/env/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/mgr/env/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/mgr/env/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/mgr/env/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [20, 3, 5, 5], expected input[10, 224, 3, 224] to have 3 channels, but got 224 channels instead

# %%
df.head()
# Out:
#                                                                                 label
# patient_id               file_name
# TCGA-3C-AALI-01A-01-T_R1 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+

# %%
# Out:
# label    hr+her2+
# Name: /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_10.png, dtype: object
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_10.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_11.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_20.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_4.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_5.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_6.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_7.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_8.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_9.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_10.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_11.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_2.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_20.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_3.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_4.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_5.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_6.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_7.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_8.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_11_9.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_10.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_11.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_2.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_20.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_3.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_4.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_5.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_6.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_7.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_8.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_12_9.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_10.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_11.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_20.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_5.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_6.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_7.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_8.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_13_9.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_14_20.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_2_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_2_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_2_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_2_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_2_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_2_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_11.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_3_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_10.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_11.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_4_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_5_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_6_13.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_6_14.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_6_15.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_6_16.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_6_17.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_6_18.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_6_19.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_7_12.png
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_7_13.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 TCGABags(df)
#
# Cell In[16], line 13, in TCGABags.__init__(self, df, mean_bag_length, var_bag_length, num_bag, seed, train)
#       9 self.r = np.random.RandomState(seed)
#      12 if self.train:
# ---> 13     self.train_bags_list, self.train_labels_list = self._form_bags(df)
#      14 else:
#      15     self.test_bags_list, self.test_labels_list = self._form_bags(df)
#
# Cell In[16], line 27, in TCGABags._form_bags(self, df)
#      25     for j in df.loc[i].index:
#      26         print(j)
# ---> 27         img = image_io.imread(j)
#      28     print(df.loc[i])
#      30 return bags_list, labels_list
#
# File ~/mgr/env/lib/python3.10/site-packages/skimage/io/_io.py:53, in imread(fname, as_gray, plugin, **plugin_args)
#      50         plugin = 'tifffile'
#      52 with file_or_url_context(fname) as fname:
# ---> 53     img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      55 if not hasattr(img, 'ndim'):
#      56     return img
#
# File ~/mgr/env/lib/python3.10/site-packages/skimage/io/manage_plugins.py:205, in call_plugin(kind, *args, **kwargs)
#     202     except IndexError:
#     203         raise RuntimeError(f'Could not find the plugin "{plugin}" for {kind}.')
# --> 205 return func(*args, **kwargs)
#
# File ~/mgr/env/lib/python3.10/site-packages/skimage/io/_plugins/imageio_plugin.py:11, in imread(*args, **kwargs)
#       9 @wraps(imageio_imread)
#      10 def imread(*args, **kwargs):
# ---> 11     out = np.asarray(imageio_imread(*args, **kwargs))
#      12     if not out.flags['WRITEABLE']:
#      13         out = out.copy()
#
# File ~/mgr/env/lib/python3.10/site-packages/imageio/v3.py:54, in imread(uri, index, plugin, extension, format_hint, **kwargs)
#      51     call_kwargs["index"] = index
#      53 with imopen(uri, "r", **plugin_kwargs) as img_file:
# ---> 54     return np.asarray(img_file.read(**call_kwargs))
#
# File ~/mgr/env/lib/python3.10/site-packages/imageio/plugins/pillow.py:252, in PillowPlugin.read(self, index, mode, rotate, apply_gamma, writeable_output, pilmode, exifrotate, as_gray)
#     249 if isinstance(index, int):
#     250     # will raise IO error if index >= number of frames in image
#     251     self._image.seek(index)
# --> 252     image = self._apply_transforms(
#     253         self._image, mode, rotate, apply_gamma, writeable_output
#     254     )
#     255 else:
#     256     iterator = self.iter(
#     257         mode=mode,
#     258         rotate=rotate,
#     259         apply_gamma=apply_gamma,
#     260         writeable_output=writeable_output,
#     261     )
#
# File ~/mgr/env/lib/python3.10/site-packages/imageio/plugins/pillow.py:333, in PillowPlugin._apply_transforms(self, image, mode, rotate, apply_gamma, writeable_output)
#     329     else:
#     330         # pillow >= 10.1.0
#     331         image = image.convert(desired_mode)
# --> 333 image = np.asarray(image)
#     335 meta = self.metadata(index=self._image.tell(), exclude_applied=False)
#     336 if rotate and "Orientation" in meta:
#
# File ~/mgr/env/lib/python3.10/site-packages/PIL/Image.py:678, in Image.__array_interface__(self)
#     676         new["data"] = self.tobytes("raw", "L")
#     677     else:
# --> 678         new["data"] = self.tobytes()
#     679 except Exception as e:
#     680     if not isinstance(e, (MemoryError, RecursionError)):
#
# File ~/mgr/env/lib/python3.10/site-packages/PIL/Image.py:737, in Image.tobytes(self, encoder_name, *args)
#     734 if encoder_name == "raw" and args == ():
#     735     args = self.mode
# --> 737 self.load()
#     739 if self.width == 0 or self.height == 0:
#     740     return b""
#
# File ~/mgr/env/lib/python3.10/site-packages/PIL/ImageFile.py:269, in ImageFile.load(self)
#     266         raise OSError(msg)
#     268 b = b + s
# --> 269 n, err_code = decoder.decode(b)
#     270 if n < 0:
#     271     break
#
# KeyboardInterrupt:

# %%
df.loc['TCGA-3C-AALI-01A-01-T_R1'].sample(10, random_state=10)#.loc['/mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA-3C-AALI-01A-01-T_R1/patch_10_10.png']
# Out:
#                                                        label
# file_name
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+

# %%
df.loc['TCGA-3C-AALI-01A-01-T_R2'].sample(10, random_state=10)
# Out:
#                                                        label
# file_name
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+

# %%
df.index.get_level_values(0).unique()
# Out:
#                                                                                 label
# patient_id               file_name
# TCGA-3C-AALI-01A-01-T_R1 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2+
# ...                                                                               ...
# TCGA-S3-AA17-01A-01-T_R2 /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2-
#                          /mnt/d/uczelnia/magister/TCGA_breast_patch/TCGA...  hr+her2-
#
# [714171 rows x 1 columns]
