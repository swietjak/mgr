# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from functools import reduce
from typing import Dict
from io import StringIO
from multiprocessing import Pool

# %%
raw_exams_df = pd.read_csv('data/TCGA_Reports.csv')
raw_exams_df.head()
# Out:
#                                     patient_filename  \
# 0  TCGA-BP-5195.25c0b433-5557-4165-922e-2c1eac9c26f0
# 1  TCGA-D7-8573.b7306a47-697d-4ed3-bbe1-81d49674a8f8
# 2  TCGA-EI-7004.13591eed-30e5-47a3-91be-7a370663d2d4
# 3  TCGA-EB-A82B.23E186C6-739C-4EF1-8788-79AA89C6E87A
# 4  TCGA-A6-3808.e1505f65-72ef-438d-a5e1-93ed8bf6635d
#
#                                                 text
# 0  Date of Recelpt: Clinical Diagnosis & History:...
# 1  Material: 1) Material: stomach, Method of coll...
# 2  page 1 / 1. copy No. 3. Examination: Histopath...
# 3  Patient ID: Gross Description: A mass is locat...
# 4  SPECIMEN. Right colon. CLINICAL NOTES. PRE-OP ...

# %%
patients_df = pd.read_excel('data/TCGA-CDR-SupplementalTableS1.xlsx')
patients_df[patients_df['type'] == 'BRCA']['bcr_patient_barcode'].unique()
# Out:
# array(['TCGA-3C-AAAU', 'TCGA-3C-AALI', 'TCGA-3C-AALJ', ...,
#        'TCGA-XX-A89A', 'TCGA-Z7-A8R5', 'TCGA-Z7-A8R6'], dtype=object)

# %%
raw_exams_df['bcr_patient_barcode'] = raw_exams_df['patient_filename'].map(lambda x: x.split('.')[0])
# print(patients_df[patients_df['type'] == 'BRCA']['bcr_patient_barcode'].unique().size, exams_df['bcr_patient_barcode'].unique().size)
exams_df = pd.concat([patients_df[patients_df['type'] == 'BRCA'], raw_exams_df], axis=1, join='inner')[['bcr_patient_barcode', 'text', 'patient_filename']]

# %%
# nltk.download("punkt")
# nltk.download("stopwords")

# %%
words_counter = nltk.FreqDist([])
def f(patient):
    return nltk.word_tokenize(patient[1])
with Pool(12) as p:
    o = p.map(f, exams_df['text'].items())

for tokens in o:
    words_counter.update(tokens)

# %%
redundant_tokens_set = set(stopwords.words('english'))
def word_filter(acc: Dict[str, int], curr: str, words_counter: nltk.FreqDist):
    if curr.lower() in redundant_tokens_set or len(curr) < 2: #or not curr.isalpha():
        return acc
    lowercase_key = curr.lower()
    if lowercase_key in acc:
        acc[lowercase_key] += words_counter[curr]
    else:
        acc[lowercase_key] = words_counter[curr]
        
    return acc

# %%
redundant_tokens_set = set(stopwords.words('english'))
filtered_words_count = reduce(lambda acc, curr: word_filter(acc, curr, words_counter), words_counter, {})
filtered_words_count
# Out:
# {'cm': 10361,
#  'lymph': 9120,
#  'tumor': 8469,
#  'nodes': 5512,
#  'tissue': 4971,
#  'margin': 4196,
#  'node': 4683,
#  'specimen': 4772,
#  '``': 3043,
#  'submitted': 3262,
#  "''": 2830,
#  'right': 5222,
#  'left': 4733,
#  'labeled': 2666,
#  'carcinoma': 3248,
#  'identified': 2540,
#  'section': 2275,
#  'measuring': 1819,
#  'mass': 1906,
#  'sections': 2217,
#  'received': 2641,
#  'soft': 1489,
#  'surface': 1326,
#  'consists': 1260,
#  'frozen': 1618,
#  'diagnosis': 2692,
#  'fresh': 1255,
#  'one': 1880,
#  'anterior': 1395,
#  'lobe': 1294,
#  'posterior': 1319,
#  'invasion': 2037,
#  'resection': 1400,
#  'negative': 2243,
#  'measures': 1100,
#  'dimension': 1125,
#  'patient': 1169,
#  'formalin': 1057,
#  '0.5': 960,
#  'present': 1521,
#  'inked': 945,
#  '1.5': 887,
#  "'s": 923,
#  'tan': 862,
#  'grade': 1687,
#  'entirely': 976,
#  'portion': 922,
#  'grossly': 918,
#  'bisected': 825,
#  'part': 1429,
#  'greatest': 1027,
#  'cells': 869,
#  '0.3': 745,
#  'c.': 790,
#  'name': 780,
#  'representative': 1274,
#  'cassette': 1037,
#  'tube': 837,
#  '10': 700,
#  'two': 1062,
#  '2.5': 677,
#  '0.2': 660,
#  'biopsy': 1198,
#  'cell': 902,
#  'renal': 914,
#  'margins': 1393,
#  'possible': 687,
#  'level': 1185,
#  'lower': 845,
#  'diameter': 691,
#  '1.0': 628,
#  'positive': 972,
#  'aggregate': 617,
#  'fallopian': 780,
#  'multiple': 916,
#  'sectioned': 609,
#  'ovary': 803,
#  'description': 1188,
#  '0.4': 596,
#  'mm': 661,
#  'wall': 670,
#  'a.': 960,
#  'type': 1244,
#  'adipose': 615,
#  '0.6': 564,
#  'parenchyma': 580,
#  'firm': 559,
#  'adenocarcinoma': 1002,
#  '2.0': 546,
#  'superior': 642,
#  'gross': 1259,
#  'nodule': 607,
#  'fat': 592,
#  'excision': 1002,
#  'histologic': 879,
#  'lesion': 621,
#  'unremarkable': 618,
#  'd.': 551,
#  'area': 557,
#  'upper': 732,
#  'clinical': 1129,
#  'attached': 548,
#  'within': 631,
#  'lateral': 599,
#  'kidney': 716,
#  'breast': 976,
#  'yellow': 515,
#  'follows': 513,
#  'segment': 617,
#  'pelvic': 828,
#  'performed': 573,
#  '3.5': 487,
#  'inferior': 564,
#  'invasive': 1034,
#  'fragments': 520,
#  'fragment': 507,
#  '0.7': 471,
#  '0.8': 470,
#  'cervix': 679,
#  'areas': 500,
#  'differentiated': 618,
#  'black': 514,
#  'length': 490,
#  'distal': 672,
#  'gland': 573,
#  'block': 927,
#  'cut': 527,
#  'seen': 613,
#  'metastatic': 857,
#  'size': 944,
#  'f.': 454,
#  'number': 916,
#  'summary': 681,
#  'prostate': 761,
#  'ureter': 549,
#  'lung': 665,
#  'mucosa': 479,
#  'duct': 465,
#  'shows': 467,
#  '4.5': 416,
#  '3.0': 413,
#  'e.': 427,
#  'single': 482,
#  '1.2': 404,
#  'container': 571,
#  'smooth': 404,
#  'b.': 407,
#  'report': 1043,
#  'sp': 389,
#  '0.1': 386,
#  'thickness': 430,
#  'cassettes': 452,
#  'additional': 862,
#  'blue': 428,
#  'pathologic': 819,
#  'uterine': 444,
#  'involved': 545,
#  'small': 482,
#  '4.0': 366,
#  'malignancy': 594,
#  'necrosis': 480,
#  'uninvolved': 526,
#  'normal': 441,
#  'ranging': 357,
#  'serially': 369,
#  'adjacent': 398,
#  'examined': 530,
#  'deep': 482,
#  'capsule': 411,
#  'findings': 542,
#  'irregular': 349,
#  'comment': 775,
#  'show': 356,
#  'proximal': 479,
#  'surgical': 958,
#  'white': 356,
#  'quadrant': 408,
#  'see': 703,
#  'neck': 487,
#  'base': 395,
#  'date': 526,
#  '11': 324,
#  '12': 324,
#  'skin': 487,
#  'history': 644,
#  'microscopic': 757,
#  'appears': 324,
#  'fibroadipose': 383,
#  'bladder': 504,
#  'three': 519,
#  'liver': 525,
#  'specified': 320,
#  'focal': 495,
#  'lesions': 330,
#  'adrenal': 449,
#  'toto': 314,
#  '0/1': 302,
#  'slice': 375,
#  'free': 520,
#  'approximately': 377,
#  'designated': 314,
#  'final': 658,
#  'outer': 355,
#  'determined': 301,
#  'external': 366,
#  'stage': 645,
#  'reveals': 310,
#  'x1': 315,
#  'site': 636,
#  'extension': 596,
#  'pathology': 488,
#  'focally': 347,
#  'cancer': 477,
#  'pleura': 321,
#  'nodules': 298,
#  'tumour': 360,
#  'benign': 637,
#  'largest': 357,
#  'reveal': 280,
#  'uterus': 542,
#  'evidence': 438,
#  'none': 343,
#  '1.3': 274,
#  'papillary': 542,
#  'also': 354,
#  'medial': 335,
#  'thyroid': 437,
#  'pancreatic': 373,
#  'examination': 485,
#  'sentinel': 524,
#  'located': 293,
#  'total': 666,
#  'results': 422,
#  'contains': 269,
#  'additionally': 292,
#  'bronchial': 393,
#  'remaining': 296,
#  'bilateral': 455,
#  'large': 328,
#  'bile': 309,
#  'staining': 316,
#  'applicable': 264,
#  'metastasis': 421,
#  'consistent': 274,
#  '0.9': 251,
#  'apex': 285,
#  'remainder': 291,
#  'high': 412,
#  '5.0': 248,
#  'seminal': 380,
#  'without': 265,
#  'squamous': 509,
#  'vein': 288,
#  '1.8': 242,
#  '--': 241,
#  'lobulated': 244,
#  'involvement': 419,
#  'endometrial': 338,
#  'a1': 239,
#  'iii': 237,
#  '5.5': 237,
#  'common': 368,
#  'case': 425,
#  'fatty': 282,
#  'extends': 266,
#  'closest': 251,
#  '1.1': 228,
#  'four': 355,
#  'aspect': 238,
#  'piece': 231,
#  'colon': 327,
#  'tests': 228,
#  '1.': 224,
#  'vascular': 384,
#  '2.2': 221,
#  'iliac': 349,
#  'addendum': 451,
#  'g.': 288,
#  'cystic': 254,
#  'consultation': 450,
#  'mid': 234,
#  'fibrous': 262,
#  'serosa': 257,
#  'well': 261,
#  'absent': 342,
#  'pink-tan': 217,
#  '1.7': 212,
#  'myometrium': 261,
#  'axillary': 365,
#  'information': 385,
#  'neoplasm': 248,
#  'pleural': 277,
#  'entire': 266,
#  'h.': 209,
#  'fda': 202,
#  'solid': 262,
#  'ln': 207,
#  'nephrectomy': 241,
#  'sectioning': 391,
#  'glistening': 202,
#  'dissection': 394,
#  'medical': 236,
#  'features': 261,
#  'brain': 509,
#  'including': 224,
#  'ii': 204,
#  'less': 231,
#  '1.4': 195,
#  'reviewed': 277,
#  'hilar': 229,
#  '15': 193,
#  'regional': 442,
#  'procedure': 422,
#  'evaluation': 212,
#  'material': 341,
#  'yellow-tan': 190,
#  'egfr': 191,
#  'hemorrhagic': 192,
#  'score': 444,
#  'pancreas': 239,
#  'endometrium': 273,
#  'tan-pink': 186,
#  '20': 185,
#  'test': 235,
#  'ajcc': 184,
#  'dimensions': 224,
#  'intraoperative': 431,
#  'performance': 183,
#  'changes': 300,
#  'pno': 201,
#  'b1': 182,
#  'candidates': 182,
#  'used': 181,
#  'red': 194,
#  'pathologist': 308,
#  'm.': 185,
#  'taken': 204,
#  'serosal': 226,
#  'omentum': 347,
#  'stitch': 212,
#  '1.6': 177,
#  'ovaries': 262,
#  'cyst': 206,
#  'long': 186,
#  'clear': 216,
#  '3.2': 176,
#  'frontal': 272,
#  'grams': 199,
#  'suture': 196,
#  'cavity': 199,
#  'brown': 177,
#  'fs': 214,
#  'nodular': 216,
#  'proliferation': 196,
#  'tnm': 172,
#  'gallbladder': 289,
#  'may': 179,
#  'side': 203,
#  '13': 171,
#  'pole': 183,
#  'characteristics': 190,
#  'synoptic': 262,
#  '2.3': 170,
#  'partial': 261,
#  'pink': 170,
#  'candidate': 174,
#  'nuclei': 185,
#  'sect': 170,
#  'aa': 171,
#  'a2': 168,
#  'fish': 170,
#  'laboratory': 316,
#  'approved': 240,
#  '6.0': 167,
#  'c1': 166,
#  'intact': 249,
#  'pcs': 165,
#  'following': 190,
#  'reported': 193,
#  'record': 197,
#  'per': 200,
#  'nuclear': 403,
#  'moderately': 338,
#  'artery': 177,
#  'primary': 397,
#  'pieces': 168,
#  'tubes': 241,
#  'foci': 205,
#  'iv': 163,
#  'code': 250,
#  'studies': 274,
#  'invades': 210,
#  'end': 240,
#  'routine': 185,
#  'noted': 181,
#  'fibrofatty': 171,
#  'time': 298,
#  'inner': 204,
#  'control': 178,
#  'developed': 157,
#  '2.8': 157,
#  'dr.': 157,
#  'stomach': 233,
#  'cleared': 155,
#  'figo': 157,
#  'diagnostic': 168,
#  'tan-white': 154,
#  'poorly': 344,
#  'component': 225,
#  'based': 237,
#  'slides': 252,
#  'drug': 152,
#  '14': 152,
#  'stains': 198,
#  'central': 198,
#  'specimens': 363,
#  'vesicle': 185,
#  'food': 150,
#  'serous': 304,
#  'nipple': 217,
#  'permanent': 245,
#  'prostatic': 247,
#  'neoplastic': 153,
#  'situ': 267,
#  'date/time': 154,
#  'blocks': 180,
#  'involving': 208,
#  'chronic': 251,
#  'green': 161,
#  'perineural': 298,
#  'personally': 144,
#  'lobular': 229,
#  'surfaces': 144,
#  'staging': 298,
#  'page': 184,
#  'hemorrhage': 150,
#  'perpendicular': 159,
#  'focus': 188,
#  'embedded': 150,
#  'given': 158,
#  'tissues': 155,
#  'immunohistochemical': 238,
#  'containing': 151,
#  '0/2': 138,
#  'dna': 137,
#  'region': 149,
#  '2.4': 137,
#  'temporal': 225,
#  '7.5': 136,
#  'pattern': 202,
#  'administration': 135,
#  'overlying': 141,
#  'associated': 202,
#  'gray': 136,
#  'source': 189,
#  'pt': 146,
#  'extending': 168,
#  'hyperplasia': 204,
#  'surrounding': 144,
#  'pmx': 165,
#  'maximum': 227,
#  'labelled': 136,
#  'tan-brown': 132,
#  'dcis': 132,
#  'bowel': 157,
#  '2.': 131,
#  'line': 142,
#  '7.0': 130,
#  'testing': 175,
#  'ductal': 300,
#  'five': 216,
#  'lumen': 134,
#  '6.5': 129,
#  'pt2': 129,
#  'change': 167,
#  'gram': 129,
#  'fibrosis': 151,
#  'mucosal': 149,
#  'fixed': 130,
#  'junction': 139,
#  'tan-yellow': 127,
#  'stain': 196,
#  'isthmus': 155,
#  'whole': 125,
#  'location': 220,
#  'extensive': 213,
#  'moderate': 163,
#  'sinus': 142,
#  'previously': 132,
#  'weighing': 123,
#  'b2': 122,
#  'vesicles': 193,
#  'vas': 138,
#  'rubbery': 123,
#  'half': 134,
#  '50': 121,
#  'greater': 154,
#  '17': 121,
#  'masses': 125,
#  'distance': 186,
#  'partially': 143,
#  'muscle': 168,
#  'hepatic': 172,
#  'gleason': 235,
#  'cervical': 199,
#  'distant': 196,
#  '3.8': 119,
#  'axilla': 203,
#  'hysterectomy': 222,
#  'space': 168,
#  'extent': 266,
#  'stapled': 127,
#  'bronchus': 124,
#  'oriented': 129,
#  'vessel': 211,
#  'overall': 144,
#  'obturator': 180,
#  'reactive': 150,
#  'found': 130,
#  'along': 124,
#  'anthracotic': 138,
#  'dissected': 123,
#  'approval': 116,
#  'sample': 172,
#  'subsequently': 116,
#  'en': 122,
#  '2.7': 116,
#  'deferens': 127,
#  'necessary': 115,
#  'yes': 126,
#  'ovarian': 146,
#  'k.': 119,
#  'pn': 120,
#  'assessed': 117,
#  'research': 138,
#  'note': 280,
#  'appearance': 125,
#  'duodenum': 139,
#  'status': 233,
#  'involves': 186,
#  'middle': 125,
#  'friable': 112,
#  'involve': 122,
#  'significant': 133,
#  'demonstrates': 118,
#  'comments': 157,
#  'mib-1': 113,
#  'inflammation': 156,
#  'away': 126,
#  'main': 116,
#  'mastectomy': 229,
#  'portions': 146,
#  'clearance': 112,
#  'gastric': 132,
#  'corpus': 115,
#  'l.': 111,
#  'available': 113,
#  'interpreted': 125,
#  '2.1': 108,
#  'neoplasia': 172,
#  'placed': 109,
#  'g2': 107,
#  'mitotic': 241,
#  'her2': 120,
#  'gene': 138,
#  'endocervical': 130,
#  'canal': 109,
#  'radical': 266,
#  'full': 130,
#  'slightly': 110,
#  'vessels': 113,
#  'appear': 106,
#  'parts': 155,
#  '0/3': 106,
#  'fundus': 113,
#  'd1': 105,
#  'wedge': 139,
#  'provided': 114,
#  'a3': 104,
#  'staple': 110,
#  'myometrial': 161,
#  'i.': 110,
#  'parenchymal': 163,
#  'depth': 162,
#  '25': 102,
#  'opened': 106,
#  'pt3': 102,
#  'mesenteric': 113,
#  'pm': 116,
#  'face': 102,
#  'purposes': 102,
#  'laterality': 167,
#  'u.s.': 100,
#  'analysis': 136,
#  'ap': 100,
#  'and/or': 163,
#  'polyp': 114,
#  'lymphovascular': 236,
#  '30': 99,
#  'unoriented': 99,
#  '4.2': 98,
#  'review': 146,
#  'tongue': 156,
#  'marked': 121,
#  'ptnm': 106,
#  'measure': 101,
#  'larger': 106,
#  "o'clock": 124,
#  'id': 98,
#  'predominantly': 106,
#  'separate': 117,
#  '8.5': 95,
#  'ink': 181,
#  'angiolymphatic': 156,
#  'remnant': 99,
#  'perinephric': 110,
#  'relation': 101,
#  'specific': 126,
#  '7th': 99,
#  'second': 131,
#  'infiltrating': 189,
#  'e1': 93,
#  'blood': 143,
#  'a5': 92,
#  'data': 198,
#  'a4': 92,
#  'cysts': 105,
#  '2.6': 91,
#  '18': 91,
#  'c2': 93,
#  '1.9': 91,
#  '1a': 95,
#  '16': 90,
#  'use': 100,
#  'mx': 119,
#  'lymphatic': 209,
#  '4r': 89,
#  'rendered': 100,
#  'differentiation': 118,
#  'adhesions': 105,
#  'pale': 90,
#  'n.': 102,
#  'micro': 92,
#  'true': 116,
#  'metastases': 160,
#  'appendix': 145,
#  'lobectomy': 165,
#  'circumscribed': 89,
#  'rt': 139,
#  'initials': 89,
#  'using': 92,
#  'er': 89,
#  'composed': 89,
#  '3.7': 87,
#  'please': 112,
#  'amount': 88,
#  'orange': 95,
#  'para-aortic': 142,
#  'variant': 97,
#  '3.': 86,
#  'clia': 86,
#  'several': 114,
#  'index': 124,
#  'prominent': 100,
#  'identification': 88,
#  '8.0': 85,
#  'disease': 121,
#  'cortex': 88,
#  'tumors': 152,
#  'apparent': 89,
#  'b3': 85,
#  'patent': 85,
#  '19q': 86,
#  'paraffin': 93,
#  'glioma': 113,
#  '40': 84,
#  'infiltration': 100,
#  'polypoid': 87,
#  'discrete': 90,
#  'mediastinal': 115,
#  'receptor': 139,
#  'paratracheal': 139,
#  'cortical': 96,
#  '1p': 93,
#  'chromosome': 106,
#  'slide': 182,
#  'es': 87,
#  'containers': 83,
#  'endomyometrium': 95,
#  'circumference': 86,
#  'demonstrate': 83,
#  'result': 130,
#  'thyroidectomy': 123,
#  'gm': 82,
#  'mild': 140,
#  'limited': 95,
#  'interpretation': 183,
#  'treatment': 154,
#  'fsc': 104,
#  'six': 148,
#  'evaluated': 91,
#  'short': 95,
#  'venous': 107,
#  'ml': 89,
#  'adnexa': 135,
#  'n1': 80,
#  'pr': 81,
#  'ratio': 113,
#  'covered': 81,
#  'diffuse': 100,
#  'endometrioid': 135,
#  'underlying': 93,
#  'include': 86,
#  '5.2': 80,
#  'first': 105,
#  'mgmt': 79,
#  'confined': 124,
#  'prior': 118,
#  'nottingham': 126,
#  'si': 81,
#  'however': 141,
#  'a6': 78,
#  'nos': 89,
#  'muscularis': 100,
#  'duodenal': 87,
#  'bone': 121,
#  'procurement': 119,
#  'propria': 93,
#  'path': 98,
#  'collected': 98,
#  'ulcerated': 108,
#  '2a': 78,
#  'range': 89,
#  'growth': 97,
#  'ihc': 76,
#  'serial': 111,
#  'sized': 77,
#  'esophagus': 114,
#  '3.3': 76,
#  'vaginal': 114,
#  'cellular': 87,
#  '3.1': 76,
#  'assay': 101,
#  'qualified': 75,
#  'perform': 78,
#  'special': 164,
#  'pelvis': 75,
#  'a7': 75,
#  'removed': 76,
#  'run': 84,
#  'revealing': 75,
#  'g3': 75,
#  'holds': 75,
#  'superficial': 103,
#  'follicular': 101,
#  'h/e': 74,
#  'lymphoid': 89,
#  'width': 79,
#  'immunohistochemistry': 184,
#  'smaller': 85,
#  'edge': 81,
#  'sex': 103,
#  'afs': 74,
#  'dysplasia': 137,
#  'required': 75,
#  'weighs': 73,
#  '90': 73,
#  'hours': 74,
#  'fixation': 82,
#  'figures': 73,
#  'operative': 178,
#  'glioblastoma': 169,
#  'peribronchial': 96,
#  'amendments': 78,
#  'shaped': 73,
#  'multiforme': 97,
#  'least': 85,
#  'ellipse': 78,
#  'fascia': 80,
#  'epithelial': 130,
#  'portal': 104,
#  'nerve': 91,
#  'salpingo-oophorectomy': 142,
#  'glands': 86,
#  'light': 103,
#  'abnormality': 91,
#  'white-tan': 72,
#  'third': 74,
#  'totally': 88,
#  'curvature': 72,
#  'ureteral': 86,
#  'matter': 77,
#  'detected': 79,
#  'markers': 94,
#  'regarded': 70,
#  'improvement': 71,
#  'internal': 86,
#  'abuts': 72,
#  'showing': 77,
#  'visceral': 125,
#  'radial': 89,
#  'pathological': 145,
#  'et': 69,
#  'suspicious': 79,
#  'formation': 91,
#  '0/4': 69,
#  '2+': 69,
#  'cuff': 74,
#  'tan-red': 69,
#  '19': 68,
#  'g1': 68,
#  'certified': 68,
#  'low': 119,
#  'urethral': 91,
#  'fsa1': 68,
#  'zone': 72,
#  'adherent': 71,
#  'extend': 70,
#  'a8': 67,
#  '9.0': 67,
#  'ampulla': 78,
#  '4.': 66,
#  'consisting': 67,
#  'pending': 103,
#  'entirety': 66,
#  'contents': 131,
#  'cord': 76,
#  'extracapsular': 115,
#  'a9': 65,
#  'c3': 65,
#  'b4': 65,
#  'fimbriated': 71,
#  'architecture': 72,
#  'periaortic': 107,
#  'head': 97,
#  'red-tan': 66,
#  'necrotic': 66,
#  'tubular': 91,
#  'signature': 89,
#  'parathyroid': 135,
#  'upon': 142,
#  'personal': 75,
#  'recut': 75,
#  '3.6': 64,
#  'reaction': 76,
#  'n/a': 111,
#  '4.8': 64,
#  'activity': 88,
#  'otherwise': 74,
#  'background': 111,
#  'classification': 104,
#  'macroscopic': 125,
#  'lab': 83,
#  'capsular': 127,
#  'answered': 63,
#  'atypia': 98,
#  'pleomorphism': 82,
#  'conducted': 66,
#  'lymph-vascular': 112,
#  'gerota': 69,
#  '60': 62,
#  'scattered': 81,
#  'levels': 102,
#  'rib': 100,
#  'cross': 85,
#  'thick': 68,
#  '4.3': 61,
#  'encapsulated': 62,
#  'complete': 106,
#  'tps': 60,
#  'marks': 73,
#  'reagents': 60,
#  'os': 63,
#  'resident': 70,
#  'forming': 60,
#  'peripheral': 77,
#  'previous': 138,
#  'respectively': 63,
#  'atypical': 94,
#  'trisected': 68,
#  'microvascular': 65,
#  'defined': 60,
#  'investigational': 63,
#  'clip': 67,
#  '21': 59,
#  'synopsis': 62,
#  'made': 59,
#  'ectocervix': 62,
#  'unifocal': 74,
#  'considered': 61,
#  'tan-gray': 59,
#  'decalcification': 64,
#  'random': 74,
#  '2.9': 58,
#  'apical': 92,
#  'd2': 58,
#  'near': 64,
#  'snomed': 58,
#  'probe': 87,
#  'infiltrates': 60,
#  'astrocytoma': 91,
#  'diffusely': 60,
#  'confirmed': 59,
#  'c4': 57,
#  'md': 57,
#  'structures': 69,
#  'expression': 67,
#  'parametrial': 70,
#  'anaplastic': 111,
#  'glial': 59,
#  'therapy': 77,
#  'amplification': 85,
#  'described': 57,
#  'well-circumscribed': 56,
#  'invade': 57,
#  'a10': 56,
#  'strong': 65,
#  'system': 61,
#  'gray-tan': 56,
#  'stained': 63,
#  'average': 70,
#  'filled': 55,
#  'mixed': 89,
#  'endocervix': 64,
#  'nearest': 69,
#  'checklist': 69,
#  'count': 79,
#  'hilum': 57,
#  'f1': 55,
#  'fleshy': 55,
#  'nci': 55,
#  'cellularity': 57,
#  'dark': 57,
#  'seven': 93,
#  'red-brown': 55,
#  'comes': 59,
#  'details': 79,
#  'cornu': 55,
#  'p53': 69,
#  'presence': 80,
#  'printed': 73,
#  '1/1': 54,
#  'a12': 54,
#  'weight': 103,
#  '3.4': 54,
#  'histopathological': 57,
#  'shaved': 56,
#  'minimal': 67,
#  'completed': 65,
#  'mitoses': 67,
#  'controls': 58,
#  'physician': 68,
#  'dr': 68,
#  'complexity': 53,
#  'residual': 79,
#  'preparation': 61,
#  'potential': 56,
#  'indurated': 55,
#  'similar': 74,
#  '9.5': 53,
#  'lesser': 61,
#  'surgeon': 60,
#  'provider': 54,
#  'cytoplasm': 54,
#  'urothelial': 132,
#  'whipple': 61,
#  'oligodendroglioma': 75,
#  'pcr': 52,
#  'ill-defined': 52,
#  'department': 56,
#  'touch': 93,
#  'slices': 55,
#  'peritoneum': 97,
#  'thin': 57,
#  'granular': 54,
#  '3a': 54,
#  'malignant': 121,
#  'non-neoplastic': 154,
#  'stain/cnt': 51,
#  'edition': 103,
#  '10.0': 51,
#  'e2': 51,
#  'esophageal': 73,
#  '0/5': 51,
#  '0.': 51,
#  'body': 76,
#  'tail': 59,
#  'urethra': 69,
#  'pulmonary': 66,
#  'peripancreatic': 100,
#  '1988': 50,
#  'mutation': 67,
#  'patients': 71,
#  'subject': 54,
#  '80': 50,
#  'multifocal': 138,
#  'replaced': 55,
#  'close': 62,
#  '23': 50,
#  'membrane': 58,
#  ...}

# %%
filtered_words_count['breast']
# Out:
# 976

# %%
with open('data/data_bcr_clinical_data_sample.txt', 'r') as f:
	bcr_sample_df = pd.read_csv(StringIO(''.join(f.readlines()[4:]).replace('[Not Available]', '')), sep='\t')
bcr_sample_df
# Out:
#         PATIENT_ID        SAMPLE_ID                       OTHER_SAMPLE_ID  \
# 0     TCGA-AR-A1AR  TCGA-AR-A1AR-01  5fa9998b-deff-493e-8a8e-dc2422192a48
# 1     TCGA-AR-A1AR  TCGA-AR-A1AR-10  c1e5beaa-6103-409d-bdd4-a86c0f210014
# 2     TCGA-BH-A1EO  TCGA-BH-A1EO-01  9d501ca9-f50d-45fc-bcc3-fee15f9771cd
# 3     TCGA-BH-A1EO  TCGA-BH-A1EO-11  fff3e5a3-4b84-4afa-bdb5-1c6b2a6626bc
# 4     TCGA-BH-A1ES  TCGA-BH-A1ES-01  aa1037f4-1414-4e05-b11a-c558a23b7e62
# ...            ...              ...                                   ...
# 2280  TCGA-E2-A1BC  TCGA-E2-A1BC-01  83ec5738-3a27-4100-83f2-8b30ae3b2fb7
# 2281  TCGA-E2-A1BC  TCGA-E2-A1BC-10  6f95b20b-cdc6-4240-9f6e-10e199ff7f97
# 2282  TCGA-E2-A1BC  TCGA-E2-A1BC-11  d221f2c8-5852-4392-b166-92b709000e78
# 2283  TCGA-E2-A1BD  TCGA-E2-A1BD-01  1ddc4c86-029f-49b5-893c-a218240d3fa4
# 2284  TCGA-E2-A1BD  TCGA-E2-A1BD-10  bfcf8e49-85b6-4353-a778-ee64c5dd31f3
#
#       SPECIMEN_CURRENT_WEIGHT  DAYS_TO_COLLECTION  \
# 0                         NaN              1416.0
# 1                         NaN              1416.0
# 2                         NaN              4330.0
# 3                         NaN              4330.0
# 4                         NaN              4242.0
# ...                       ...                 ...
# 2280                      NaN               275.0
# 2281                      NaN               275.0
# 2282                      NaN               275.0
# 2283                      NaN               260.0
# 2284                      NaN               260.0
#
#       DAYS_TO_SPECIMEN_COLLECTION  SPECIMEN_FREEZING_METHOD  INITIAL_WEIGHT  \
# 0                             NaN                       NaN           250.0
# 1                             NaN                       NaN             NaN
# 2                             NaN                       NaN           100.0
# 3                             NaN                       NaN           250.0
# 4                             NaN                       NaN           220.0
# ...                           ...                       ...             ...
# 2280                          NaN                       NaN           100.0
# 2281                          NaN                       NaN             NaN
# 2282                          NaN                       NaN           260.0
# 2283                          NaN                       NaN           100.0
# 2284                          NaN                       NaN             NaN
#
#       SPECIMEN_SECOND_LONGEST_DIMENSION IS_FFPE  ...  \
# 0                                   NaN      NO  ...
# 1                                   NaN      NO  ...
# 2                                   NaN      NO  ...
# 3                                   NaN      NO  ...
# 4                                   NaN      NO  ...
# ...                                 ...     ...  ...
# 2280                                NaN      NO  ...
# 2281                                NaN      NO  ...
# 2282                                NaN      NO  ...
# 2283                                NaN      NO  ...
# 2284                                NaN      NO  ...
#
#                      PATHOLOGY_REPORT_UUID           SAMPLE_TYPE  \
# 0     747FB91B-F523-4FA0-91DD-6014EF55643D         Primary Tumor
# 1                                      NaN  Blood Derived Normal
# 2     A2B755DD-00C4-4349-8E11-C1196EBC91D3         Primary Tumor
# 3                                      NaN   Solid Tissue Normal
# 4     9B2253AB-2C41-4E7A-9178-B690FFD9FF78         Primary Tumor
# ...                                    ...                   ...
# 2280  817D4725-01FE-4148-A8FC-3431F28D5CD8         Primary Tumor
# 2281                                   NaN  Blood Derived Normal
# 2282                                   NaN   Solid Tissue Normal
# 2283  DF746E32-AD2F-49CB-9AA6-4F8494C16B20         Primary Tumor
# 2284                                   NaN  Blood Derived Normal
#
#       SAMPLE_TYPE_ID  SHORTEST_DIMENSION TIME_BETWEEN_CLAMPING_AND_FREEZING  \
# 0                  1                 NaN                                NaN
# 1                 10                 NaN                                NaN
# 2                  1                 NaN                                NaN
# 3                 11                 NaN                                NaN
# 4                  1                 NaN                                NaN
# ...              ...                 ...                                ...
# 2280               1                 NaN                                NaN
# 2281              10                 NaN                                NaN
# 2282              11                 NaN                                NaN
# 2283               1                 NaN                                NaN
# 2284              10                 NaN                                NaN
#
#      TIME_BETWEEN_EXCISION_AND_FREEZING VIAL_NUMBER  ONCOTREE_CODE  \
# 0                                   NaN           A            IDC
# 1                                   NaN           A            NaN
# 2                                   NaN           A           MDLC
# 3                                   NaN           A            NaN
# 4                                   NaN           A            IDC
# ...                                 ...         ...            ...
# 2280                                NaN           A            ILC
# 2281                                NaN           A            NaN
# 2282                                NaN           A            NaN
# 2283                                NaN           A            IDC
# 2284                                NaN           A            NaN
#
#         CANCER_TYPE                       CANCER_TYPE_DETAILED
# 0     Breast Cancer           Breast Invasive Ductal Carcinoma
# 1               NaN                                        NaN
# 2     Breast Cancer  Breast Mixed Ductal and Lobular Carcinoma
# 3               NaN                                        NaN
# 4     Breast Cancer           Breast Invasive Ductal Carcinoma
# ...             ...                                        ...
# 2280  Breast Cancer          Breast Invasive Lobular Carcinoma
# 2281            NaN                                        NaN
# 2282            NaN                                        NaN
# 2283  Breast Cancer           Breast Invasive Ductal Carcinoma
# 2284            NaN                                        NaN
#
# [2285 rows x 25 columns]

# %%
unique_disease_vocab = set([word.lower().replace(',', '') for word in " ".join(bcr_sample_df['CANCER_TYPE_DETAILED'].dropna().unique()).split()]) - redundant_tokens_set
deases_word_counts = {word: filtered_words_count[word] if word in filtered_words_count else 0 for word in unique_disease_vocab}
print(bcr_sample_df['CANCER_TYPE_DETAILED'].dropna().unique())
deases_word_counts
# Out:
# ['Breast Invasive Ductal Carcinoma'
#  'Breast Mixed Ductal and Lobular Carcinoma'
#  'Breast Invasive Mixed Mucinous Carcinoma'
#  'Breast Invasive Lobular Carcinoma' 'Paget Disease of the Nipple'
#  'Adenoid Cystic Breast Cancer' 'Invasive Breast Carcinoma'
#  'Basal Cell Carcinoma' 'Metaplastic Breast Cancer'
#  'Solid Papillary Carcinoma of the Breast'
#  'Malignant Phyllodes Tumor of the Breast'
#  'Breast Invasive Carcinoma, NOS']
# {'cancer': 477,
#  'mucinous': 54,
#  'mixed': 89,
#  'breast': 976,
#  'phyllodes': 0,
#  'ductal': 300,
#  'invasive': 1034,
#  'disease': 121,
#  'paget': 8,
#  'papillary': 542,
#  'cell': 902,
#  'metaplastic': 3,
#  'lobular': 229,
#  'malignant': 121,
#  'solid': 262,
#  'tumor': 8469,
#  'cystic': 254,
#  'basal': 29,
#  'nipple': 217,
#  'adenoid': 0,
#  'nos': 89,
#  'carcinoma': 3248}

# %%
statistics_df = pd.DataFrame({
	'word': filtered_words_count.keys(),
 	'counts': [filtered_words_count[word] for word in filtered_words_count.keys()],
  	'indicatesDisease': [word in deases_word_counts for word in filtered_words_count.keys()]
})

# %%
statistics_df.to_csv('word_stats.csv')

# %%
with open('data/data_bcr_clinical_data_patient 1.txt', 'r') as f:
	bcr_patient_df = pd.read_csv(StringIO(''.join(f.readlines()[4:]).replace('[Not Available]', '').replace('[Not Applicable]', '')), sep='\t')
bcr_patient_df.columns.values
# Out:
# array(['OTHER_PATIENT_ID', 'PATIENT_ID', 'FORM_COMPLETION_DATE',
#        'PROSPECTIVE_COLLECTION', 'RETROSPECTIVE_COLLECTION',
#        'DAYS_TO_BIRTH', 'GENDER', 'MENOPAUSE_STATUS', 'RACE', 'ETHNICITY',
#        'HISTORY_OTHER_MALIGNANCY', 'HISTORY_NEOADJUVANT_TRTYN',
#        'TUMOR_STATUS', 'VITAL_STATUS', 'DAYS_TO_LAST_FOLLOWUP',
#        'DAYS_TO_DEATH', 'RADIATION_TREATMENT_ADJUVANT',
#        'PHARMACEUTICAL_TX_ADJUVANT', 'HISTOLOGICAL_SUBTYPE',
#        'INITIAL_PATHOLOGIC_DX_YEAR', 'AGE',
#        'METHOD_OF_INITIAL_SAMPLE_PROCUREMENT',
#        'METHOD_OF_INITIAL_SAMPLE_PROCUREMENT_OTHER',
#        'SURGICAL_PROCEDURE_FIRST', 'FIRST_SURGICAL_PROCEDURE_OTHER',
#        'PATH_MARGIN', 'SURGERY_FOR_POSITIVE_MARGINS',
#        'SURGERY_FOR_POSITIVE_MARGINS_OTHER', 'MARGIN_STATUS_REEXCISION',
#        'STAGING_SYSTEM', 'STAGING_SYSTEM_OTHER',
#        'MICROMET_DETECTION_BY_IHC', 'LYMPH_NODES_EXAMINED',
#        'LYMPH_NODE_EXAMINED_COUNT', 'LYMPH_NODES_EXAMINED_HE_COUNT',
#        'LYMPH_NODES_EXAMINED_IHC_COUNT', 'AJCC_STAGING_EDITION',
#        'AJCC_TUMOR_PATHOLOGIC_PT', 'AJCC_NODES_PATHOLOGIC_PN',
#        'AJCC_METASTASIS_PATHOLOGIC_PM', 'AJCC_PATHOLOGIC_TUMOR_STAGE',
#        'METASTATIC_SITE', 'METASTATIC_SITE_OTHER', 'ER_STATUS_BY_IHC',
#        'ER_STATUS_IHC_PERCENT_POSITIVE', 'ER_POSITIVITY_SCALE_USED',
#        'IHC_SCORE', 'ER_POSITIVITY_SCALE_OTHER',
#        'BRACHYTHERAPY_TOTAL_DOSE_POINT_A', 'PR_STATUS_BY_IHC',
#        'PR_STATUS_IHC_PERCENT_POSITIVE', 'PR_POSITIVITY_SCALE_USED',
#        'PR_POSITIVITY_IHC_INTENSITY_SCORE', 'PR_POSITIVITY_SCALE_OTHER',
#        'PR_POSITIVITY_DEFINE_METHOD', 'IHC_HER2',
#        'HER2_IHC_PERCENT_POSITIVE', 'HER2_IHC_SCORE',
#        'HER2_POSITIVITY_SCALE_OTHER', 'HER2_POSITIVITY_METHOD_TEXT',
#        'HER2_FISH_STATUS', 'HER2_COPY_NUMBER', 'CENT17_COPY_NUMBER',
#        'HER2_AND_CENT17_CELLS_COUNT', 'HER2_CENT17_RATIO',
#        'HER2_AND_CENT17_SCALE_OTHER', 'HER2_FISH_METHOD',
#        'NEW_TUMOR_EVENT_AFTER_INITIAL_TREATMENT', 'NTE_ER_STATUS',
#        'NTE_ER_STATUS_IHC__POSITIVE', 'NTE_ER_IHC_INTENSITY_SCORE',
#        'NTE_ER_POSITIVITY_OTHER_SCALE', 'NTE_ER_POSITIVITY_DEFINE_METHOD',
#        'NTE_PR_STATUS_BY_IHC', 'NTE_PR_STATUS_IHC__POSITIVE',
#        'NTE_PR_IHC_INTENSITY_SCORE', 'NTE_PR_POSITIVITY_OTHER_SCALE',
#        'NTE_PR_POSITIVITY_DEFINE_METHOD', 'NTE_HER2_STATUS',
#        'NTE_HER2_STATUS_IHC__POSITIVE', 'NTE_HER2_POSITIVITY_IHC_SCORE',
#        'NTE_HER2_POSITIVITY_OTHER_SCALE', 'NTE_HER2_POSITIVITY_METHOD',
#        'NTE_HER2_FISH_STATUS', 'NTE_HER2_SIGNAL_NUMBER',
#        'NTE_CENT_17_SIGNAL_NUMBER', 'HER2_CENT17_COUNTED_CELLS_COUNT',
#        'NTE_CENT_17_HER2_RATIO', 'NTE_CENT17_HER2_OTHER_SCALE',
#        'NTE_HER2_FISH_DEFINE_METHOD', 'PRIMARY_SITE', 'CLIN_M_STAGE',
#        'CLIN_N_STAGE', 'CLIN_T_STAGE', 'CLINICAL_STAGE',
#        'DAYS_TO_INITIAL_PATHOLOGIC_DIAGNOSIS',
#        'DAYS_TO_PATIENT_PROGRESSION_FREE', 'DAYS_TO_TUMOR_PROGRESSION',
#        'DISEASE_CODE', 'EXTRANODAL_INVOLVEMENT', 'HISTOLOGICAL_DIAGNOSIS',
#        'ICD_10', 'ICD_O_3_HISTOLOGY', 'ICD_O_3_SITE',
#        'INFORMED_CONSENT_VERIFIED', 'METASTATIC_TUMOR_INDICATOR',
#        'PROJECT_CODE', 'PRIMARY_SITE_OTHER', 'STAGE_OTHER',
#        'TISSUE_SOURCE_SITE', 'TUMOR_TISSUE_SITE', 'OS_STATUS',
#        'OS_MONTHS', 'DFS_STATUS', 'DFS_MONTHS'], dtype=object)

# %%
exams_df
# Out:
#      bcr_patient_barcode bcr_patient_barcode  \
# 504         TCGA-3C-AAAU        TCGA-HT-8111
# 505         TCGA-3C-AALI        TCGA-06-6389
# 506         TCGA-3C-AALJ        TCGA-73-A9RS
# 507         TCGA-3C-AALK        TCGA-10-0935
# 508         TCGA-4H-AAAK        TCGA-SR-A6MS
# ...                  ...                 ...
# 1596        TCGA-WT-AB44        TCGA-CN-A49A
# 1597        TCGA-XX-A899        TCGA-A8-A09K
# 1598        TCGA-XX-A89A        TCGA-N7-A4Y0
# 1599        TCGA-Z7-A8R5        TCGA-RM-A68T
# 1600        TCGA-Z7-A8R6        TCGA-BR-8381
#
#                                                    text  \
# 504   Tumor: Normal: Addendum Diagnosis: Anaplastic ...
# 505   CLINICAL HISTORY. Brain tumor. OPERATIVE DIAGN...
# 506   SPECIMENS: A. 4R LYMPH NODE. B. ADDITIONAL 4R ...
# 507   (A) RIGHT TUBE AND OVARY: HIGH-GRADE PAPILLARY...
# 508   Specimen: Procedure: Medical Record #: Accessi...
# ...                                                 ...
# 1596  Report Type. Date of Event. M. Authored by. Ho...
# 1597  Diagnosis: 4. Resected material from'l left br...
# 1598  Service : Gynecology. Gender: F. MRN. Physicia...
# 1599  Microscopic Discussion: Sections demonstrate a...
# 1600  Patient ID: Gross Description: Stomach part wi...
#
#                                        patient_filename
# 504   TCGA-HT-8111.9de92ba0-f9d6-4f7b-8a92-548082b49288
# 505   TCGA-06-6389.8ca0ae5b-4448-4f8b-8cdc-50e6209ced26
# 506   TCGA-73-A9RS.7E029394-80EC-4B53-829E-8F1DA476D648
# 507   TCGA-10-0935.f9111190-c01e-4fe7-a1db-be0434f1365f
# 508   TCGA-SR-A6MS.A37F899E-D942-455B-B90F-CE52A66894E9
# ...                                                 ...
# 1596  TCGA-CN-A49A.38A7951F-DDA7-4F2E-BF50-976459D3048C
# 1597  TCGA-A8-A09K.56C24ABB-CF1D-447F-A5A8-B762C4B01566
# 1598  TCGA-N7-A4Y0.04D78BF5-445D-4F04-90ED-4AC0C8995915
# 1599  TCGA-RM-A68T.49F14C96-CA57-469E-9615-FED1F902ED95
# 1600  TCGA-BR-8381.C6F1CEC0-F54F-40D8-9946-1E20844B3C6F
#
# [1097 rows x 4 columns]

# %%
bcr_patient_df['OS_STATUS'].unique()
# Out:
# array(['LIVING', 'DECEASED'], dtype=object)
